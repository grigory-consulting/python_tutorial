# %%
# %pip install sqlalchemy pymysql python-dotenv
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from sqlalchemy import create_engine
from dotenv import load_dotenv
import os # Betriebssystem-Tools

#load_dotenv()

os.environ["MYSQL_USER"]

# Bitte NIE so: 

# MYSQL_USER = 'dein_user'
# MYSQL_PASS = 'dein_passwort'
# MYSQL_HOST = 'localhost'  # oder echte IP/Domain deines Servers
# MYSQL_PORT = 3306         # Standardport
# MYSQL_DB   = 'deine_datenbank'




#db_url = f"mysql+pymysql://{MYSQL_USER}:{MYSQL_PASS}@{MYSQL_HOST}:{MYSQL_PORT}/{MYSQL_DB}"

os.environ
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 8
#       4 import os # Betriebssystem-Tools
#       6 #load_dotenv()
# ----> 8 os.environ["MYSQL_USER"]
#      10 # Bitte NIE so:
#      11
#      12 # MYSQL_USER = 'dein_user'
#    (...)     20
#      21 #db_url = f"mysql+pymysql://{MYSQL_USER}:{MYSQL_PASS}@{MYSQL_HOST}:{MYSQL_PORT}/{MYSQL_DB}"
#      23 os.environ
#
# File <frozen os>:714, in __getitem__(self, key)
#
# KeyError: 'MYSQL_USER'

# %%
import sqlite3


with sqlite3.connect("personal.db") as con:
    df = pd.read_sql("SELECT * FROM personal", con)
    df2 = pd.read_sql("SELECT Vorname, Nachname, Gehalt_m FROM personal WHERE Gehalt_m > 40000", con)

df
df2
# Out:
#            Vorname     Nachname  Gehalt_m
# 0             Nils  Ditschlerin     86595
# 1            Laura       Hornig     77708
# 2             Ella     Schuster    118794
# 3        Roselinde       Söding     46124
# 4          Juliana      Steckel     75834
# ...            ...          ...       ...
# 25819    Charlotte     Stiebitz     92091
# 25820  Franz-Xaver       Reuter     76610
# 25821       Alexei        Nette     54179
# 25822      Karolin       Weller     78911
# 25823       Ildiko         Bähr     47855
#
# [25824 rows x 3 columns]

# %%
with sqlite3.connect("personal.db") as con:
    for chunk in pd.read_sql("SELECT * FROM personal",con,chunksize=10000):
        print(chunk.shape)
# Out:
# (10000, 18)
# (10000, 18)
# (10000, 18)

# %%
df
# Out:
#                               MitarbeiterID Dienstnummer     Vorname  \
# 0      413885b6-da63-4e89-a887-926f6cc40b9f    NZ8637335        Nils
# 1      be400057-3025-422f-be87-d53f96a94451    GR9519484       Laura
# 2      aa5db6ab-e4f6-44c5-b2e6-ca14a2a4904a    CB2082368    Hellmuth
# 3      74ad6f76-82af-41ca-98f0-abadcb11a334    XT9496056  Maximilian
# 4      3827345c-a7d3-4ad5-bfb8-f249c754a965    NN5363995        Ella
# ...                                     ...          ...         ...
# 29995  8cb27457-479c-4cea-bed9-a281f94b105c    WG9192628      Alexei
# 29996  819cf7fb-8511-460b-87ae-950f45e8c0a1    BE4301155      Hanife
# 29997  3eece68a-9cc2-482c-ac5b-614e9d9aab33    WV8694163     Karolin
# 29998  60546bb4-371f-49c8-a0f1-fd11666942ee    RD5262073       Ilias
# 29999  b967a472-3220-4a9b-997a-a7e16e201fd2    EO9507575      Ildiko
#
#           Nachname Geburtsdatum Geschlecht  \
# 0      Ditschlerin   1963-04-06     divers
# 1           Hornig   2002-04-27   männlich
# ...

# %%
df.shape
# Out:
# (30000, 18)

# %%
df
# Out:
#                               MitarbeiterID Dienstnummer     Vorname  \
# 0      413885b6-da63-4e89-a887-926f6cc40b9f    NZ8637335        Nils
# 1      be400057-3025-422f-be87-d53f96a94451    GR9519484       Laura
# 2      aa5db6ab-e4f6-44c5-b2e6-ca14a2a4904a    CB2082368    Hellmuth
# 3      74ad6f76-82af-41ca-98f0-abadcb11a334    XT9496056  Maximilian
# 4      3827345c-a7d3-4ad5-bfb8-f249c754a965    NN5363995        Ella
# ...                                     ...          ...         ...
# 29995  8cb27457-479c-4cea-bed9-a281f94b105c    WG9192628      Alexei
# 29996  819cf7fb-8511-460b-87ae-950f45e8c0a1    BE4301155      Hanife
# 29997  3eece68a-9cc2-482c-ac5b-614e9d9aab33    WV8694163     Karolin
# 29998  60546bb4-371f-49c8-a0f1-fd11666942ee    RD5262073       Ilias
# 29999  b967a472-3220-4a9b-997a-a7e16e201fd2    EO9507575      Ildiko
#
#           Nachname Geburtsdatum Geschlecht  \
# 0      Ditschlerin   1963-04-06     divers
# 1           Hornig   2002-04-27   männlich
# ...
