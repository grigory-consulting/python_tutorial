# %%
# %pip install pandas
# Out:
# Requirement already satisfied: pandas in /Users/grigo/gits/seminars/gfu/Python_individuell/.venv/lib/python3.12/site-packages (2.3.1)
# Requirement already satisfied: numpy>=1.26.0 in /Users/grigo/gits/seminars/gfu/Python_individuell/.venv/lib/python3.12/site-packages (from pandas) (2.3.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/grigo/gits/seminars/gfu/Python_individuell/.venv/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/grigo/gits/seminars/gfu/Python_individuell/.venv/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/grigo/gits/seminars/gfu/Python_individuell/.venv/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /Users/grigo/gits/seminars/gfu/Python_individuell/.venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from faker import Faker
import random
import pandas as pd 
fake = Faker("de_DE")

# %%
def random_gender():
    return random.choice(["männlich", "weiblich", 'divers'])

def random_blood_type():
    return random.choice(["A+", "A-", "B+", "B-","O+", "O-","AB+","AB-"])

def random_smoker():
    return random.choice([True, False])

def random_allergies():
    return random.choice(["keine", "Pollen", "Nüsse", "Milch", "Gluten"])

def random_family_status():
    return random.choice(["ledig", "verheiratet", "geschieden", "verwitwet"])

# %%
patienten = []

for _ in range(50000):
    patient = {
    "PatientenID": fake.unique.uuid4(),
    "Versichertennummer": fake.bothify("??#######").upper(), # zwei Mal Buchstabe, 6 mal Zahl
    "Vorname": fake.first_name(),
    "Nachname": fake.last_name(),
    "Geburtsdatum": fake.date_of_birth(minimum_age=1, maximum_age=99),
    "Geschlecht": random_gender(),
    "Adresse": fake.address().replace('\n', ', '), # Bei Adresse die Neuzeilen durch Komma+Leerzeichen ersetzen
    "Telefon": fake.phone_number(),
    "Email": fake.unique.email(),
    "Blutgruppe": random_blood_type(),
    "Letzer_Besuch": fake.date_this_year(),
    "Hausarzt": f"{fake.first_name()} {fake.last_name()}",
    "Größe_cm":  random.randint(140, 220),
    "Gewicht_kg": random.randint(40, 130),
    "Raucher": random_smoker(),
    "Allergien": random_allergies(),
    "Letzes_EKG": fake.date_this_year(),
    "BMI": round(random.uniform(18,36),1), # Zufallszahl 
    "Familienstand": random_family_status(),
    "Beruf": fake.job(),
}
    patienten.append(patient)

patienten
# Out:
# [{'PatientenID': 'b24ff43e-a903-4789-b2f6-4056773e3a06',
#   'Versichertennummer': 'AQ2755005',
#   'Vorname': 'Svetlana',
#   'Nachname': 'Scholz',
#   'Geburtsdatum': datetime.date(1975, 3, 11),
#   'Geschlecht': 'weiblich',
#   'Adresse': 'Fechnerring 6-5, 88532 Erding',
#   'Telefon': '07311 236676',
#   'Email': 'heckertabea@example.net',
#   'Blutgruppe': 'A-',
#   'Letzer_Besuch': datetime.date(2025, 3, 1),
#   'Hausarzt': 'Cäcilie Kabus',
#   'Größe_cm': 149,
#   'Gewicht_kg': 74,
#   'Raucher': True,
#   'Allergien': 'Nüsse',
#   'Letzes_EKG': datetime.date(2025, 5, 29),
#   'BMI': 28.4,
#   'Familienstand': 'geschieden',
#   'Beruf': 'Techniker'},
#  {'PatientenID': 'fbffa844-ec1d-4f20-9a0b-5474dfcaf702',
#   'Versichertennummer': 'XB8073653',
#   'Vorname': 'Linda',
#   'Nachname': 'Ackermann',
#   'Geburtsdatum': datetime.date(1978, 3, 17),
#   'Geschlecht': 'divers',
#   'Adresse': 'Wähnerweg 7/5, 57649 Euskirchen',
#   'Telefon': '+49(0)6282711059',
#   'Email': 'kargerene@example.org',
#   'Blutgruppe': 'AB+',
#   'Letzer_Besuch': datetime.date(2025, 4, 28),
#   'Hausarzt': 'Konstanze Binner',
#   'Größe_cm': 190,
#   'Gewicht_kg': 63,
#   'Raucher': False,
#   'Allergien': 'Pollen',
#   'Letzes_EKG': datetime.date(2025, 4, 20),
#   'BMI': 30.4,
#   'Familienstand': 'ledig',
#   'Beruf': 'Friseur'},
#  {'PatientenID': '65d26661-3f6a-4d52-847d-d722d7d0cc25',
#   'Versichertennummer': 'XC1598876',
#   'Vorname': 'Karoline',
#   'Nachname': 'Jüttner',
#   'Geburtsdatum': datetime.date(1937, 9, 27),
#   'Geschlecht': 'weiblich',
#   'Adresse': 'Frida-Höfig-Ring 41/17, 37134 Dachau',
#   'Telefon': '+49(0)7142 95095',
#   'Email': 'joachimjunitz@example.net',
#   'Blutgruppe': 'A+',
#   'Letzer_Besuch': datetime.date(2025, 3, 11),
#   'Hausarzt': 'Constance Hermighausen',
#   'Größe_cm': 169,
#   'Gewicht_kg': 68,
#   'Raucher': True,
#   'Allergien': 'Pollen',
#   'Letzes_EKG': datetime.date(2025, 7, 10),
#   'BMI': 26.5,
#   'Familienstand': 'geschieden',
#   'Beruf': 'Bäcker'},
#  {'PatientenID': 'def9fe72-2ba0-44d8-bbf5-fe9c8df803a1',
#   'Versichertennummer': 'HP3422006',
#   'Vorname': 'Andrew',
#   'Nachname': 'Kobelt',
#   'Geburtsdatum': datetime.date(1960, 9, 23),
#   'Geschlecht': 'weiblich',
#   'Adresse': 'Ole-Schmiedt-Straße 38, 42082 Hechingen',
#   'Telefon': '06705 142476',
#   'Email': 'wilhelminelehmann@example.com',
#   'Blutgruppe': 'B-',
#   'Letzer_Besuch': datetime.date(2025, 3, 24),
#   'Hausarzt': 'Erdogan Sauer',
#   'Größe_cm': 145,
#   'Gewicht_kg': 87,
#   'Raucher': False,
#   'Allergien': 'Milch',
#   'Letzes_EKG': datetime.date(2025, 7, 25),
#   'BMI': 30.6,
#   'Familienstand': 'verwitwet',
#   'Beruf': 'Beamter'},
#  {'PatientenID': 'da1bc0e2-73bd-4ccb-abb5-0b6b180266a1',
#   'Versichertennummer': 'SP6375505',
#   'Vorname': 'James',
#   'Nachname': 'Stiffel',
#   'Geburtsdatum': datetime.date(1951, 6, 21),
#   'Geschlecht': 'divers',
#   'Adresse': 'Wolfgang-Förster-Gasse 65/17, 16662 Roth',
#   'Telefon': '+49(0)1601 00257',
#   'Email': 'ulrike39@example.org',
#   'Blutgruppe': 'AB-',
#   'Letzer_Besuch': datetime.date(2025, 7, 28),
#   'Hausarzt': 'Marie-Therese Wiek',
#   'Größe_cm': 175,
#   'Gewicht_kg': 123,
#   'Raucher': False,
#   'Allergien': 'Milch',
#   'Letzes_EKG': datetime.date(2025, 3, 10),
#   'BMI': 32.7,
#   'Familienstand': 'ledig',
#   'Beruf': 'Chirurgiemechaniker'},
#  {'PatientenID': '3cacc5de-ec2a-44f2-a340-7d3eecd3352b',
#   'Versichertennummer': 'PG9563299',
#   'Vorname': 'Folkert',
#   'Nachname': 'Mühle',
#   'Geburtsdatum': datetime.date(2004, 11, 25),
#   'Geschlecht': 'divers',
#   'Adresse': 'Florence-Karge-Weg 378, 32779 Forchheim',
#   'Telefon': '(05372) 589718',
#   'Email': 'bennodietz@example.com',
#   'Blutgruppe': 'A+',
#   'Letzer_Besuch': datetime.date(2025, 6, 20),
#   'Hausarzt': 'Ortwin Freudenberger',
#   'Größe_cm': 160,
#   'Gewicht_kg': 75,
#   'Raucher': False,
#   'Allergien': 'Nüsse',
#   'Letzes_EKG': datetime.date(2025, 1, 14),
#   'BMI': 29.3,
#   'Familienstand': 'verheiratet',
#   'Beruf': 'Ausbaufacharbeiter'},
#  {'PatientenID': 'b27d2dcc-8457-40fd-9581-7f4a8934ab3b',
#   'Versichertennummer': 'OS9331247',
#   'Vorname': 'Amir',
#   'Nachname': 'Heß',
#   'Geburtsdatum': datetime.date(1990, 10, 3),
#   'Geschlecht': 'divers',
#   'Adresse': 'Margret-Säuberlich-Ring 4/5, 43157 Eisenhüttenstadt',
#   'Telefon': '+49 (0) 7729 632372',
#   'Email': 'zwirth@example.com',
#   'Blutgruppe': 'B-',
#   'Letzer_Besuch': datetime.date(2025, 4, 15),
#   'Hausarzt': 'Ines Dowerg',
#   'Größe_cm': 210,
#   'Gewicht_kg': 82,
#   'Raucher': False,
#   'Allergien': 'Gluten',
#   'Letzes_EKG': datetime.date(2025, 2, 20),
#   'BMI': 25.2,
#   'Familienstand': 'verheiratet',
#   'Beruf': 'Friseur'},
#  {'PatientenID': '2a38c998-2412-4551-89bb-ea30fe16ea6f',
#   'Versichertennummer': 'QV1422301',
#   'Vorname': 'Danilo',
#   'Nachname': 'Ernst',
#   'Geburtsdatum': datetime.date(1994, 7, 5),
#   'Geschlecht': 'weiblich',
#   'Adresse': 'Trommlerplatz 27, 36800 Steinfurt',
#   'Telefon': '+49(0)8941 28175',
#   'Email': 'gueltenlange@example.com',
#   'Blutgruppe': 'A+',
#   'Letzer_Besuch': datetime.date(2025, 2, 10),
#   'Hausarzt': 'Pius Bähr',
#   'Größe_cm': 161,
#   'Gewicht_kg': 41,
#   'Raucher': False,
#   'Allergien': 'Pollen',
#   'Letzes_EKG': datetime.date(2025, 2, 17),
#   'BMI': 31.6,
#   'Familienstand': 'verheiratet',
#   'Beruf': 'Koreanistiker'},
#  {'PatientenID': 'e07d4739-8d34-4b46-b638-d158361066c2',
#   'Versichertennummer': 'ZR6900724',
#   'Vorname': 'Heiner',
#   'Nachname': 'Trapp',
#   'Geburtsdatum': datetime.date(1953, 9, 29),
#   'Geschlecht': 'divers',
#   'Adresse': 'André-Bärer-Allee 7/4, 87262 Eggenfelden',
#   'Telefon': '0018694646',
#   'Email': 'steckeldarko@example.org',
#   'Blutgruppe': 'AB-',
#   'Letzer_Besuch': datetime.date(2025, 1, 15),
#   'Hausarzt': 'Gaby Bloch',
#   'Größe_cm': 169,
#   'Gewicht_kg': 53,
#   'Raucher': True,
#   'Allergien': 'Gluten',
#   'Letzes_EKG': datetime.date(2025, 5, 10),
#   'BMI': 21.7,
#   'Familienstand': 'ledig',
#   'Beruf': 'Designer'},
#  {'PatientenID': 'fefaa244-30bf-4d10-a889-289393781443',
#   'Versichertennummer': 'NU2272781',
#   'Vorname': 'Galina',
#   'Nachname': 'Gnatz',
#   'Geburtsdatum': datetime.date(2018, 1, 23),
#   'Geschlecht': 'divers',
#   'Adresse': 'Leila-Stroh-Ring 1-4, 49414 Bischofswerda',
#   'Telefon': '0765777254',
#   'Email': 'karztabea@example.net',
#   'Blutgruppe': 'O-',
#   'Letzer_Besuch': datetime.date(2025, 1, 17),
#   'Hausarzt': 'Therese Bien',
#   'Größe_cm': 162,
#   'Gewicht_kg': 126,
#   'Raucher': True,
#   'Allergien': 'Pollen',
#   'Letzes_EKG': datetime.date(2025, 6, 6),
#   'BMI': 27.9,
#   'Familienstand': 'geschieden',
#   'Beruf': 'Pfleger'},
#  {'PatientenID': '87fc1d74-84c3-4c26-a11b-ef81905150bb',
#   'Versichertennummer': 'DS7840745',
#   'Vorname': 'Erkan',
#   'Nachname': 'Wiek',
#   'Geburtsdatum': datetime.date(1932, 2, 9),
#   'Geschlecht': 'weiblich',
#   'Adresse': 'Mustafa-Scheuermann-Gasse 1/8, 37240 Günzburg',
#   'Telefon': '(04923) 056133',
#   'Email': 'mustafahenck@example.com',
#   'Blutgruppe': 'A-',
#   'Letzer_Besuch': datetime.date(2025, 6, 14),
#   'Hausarzt': 'Conrad Spieß',
#   'Größe_cm': 157,
#   'Gewicht_kg': 40,
#   'Raucher': False,
#   'Allergien': 'Gluten',
#   'Letzes_EKG': datetime.date(2025, 3, 15),
#   'BMI': 20.0,
#   'Familienstand': 'verwitwet',
#   'Beruf': 'Schornsteinfeger'},
#  {'PatientenID': '6f419d89-5ccf-48ca-ad83-fe09cf8cf9ad',
#   'Versichertennummer': 'EX3169327',
#   'Vorname': 'Bernt',
#   'Nachname': 'Löchel',
#   'Geburtsdatum': datetime.date(2017, 12, 7),
#   'Geschlecht': 'männlich',
#   'Adresse': 'Birnbaumplatz 3189, 85557 Plauen',
#   'Telefon': '+49(0)5882 75798',
#   'Email': 'mohaupttorben@example.org',
#   'Blutgruppe': 'AB-',
#   'Letzer_Besuch': datetime.date(2025, 3, 23),
#   'Hausarzt': 'Philippe Schmiedecke',
#   'Größe_cm': 191,
#   'Gewicht_kg': 70,
#   'Raucher': True,
#   'Allergien': 'Nüsse',
#   'Letzes_EKG': datetime.date(2025, 6, 4),
#   'BMI': 29.6,
#   'Familienstand': 'verwitwet',
#   'Beruf': 'Winzer'},
#  {'PatientenID': 'c86a3c2c-6f70-4dc6-b2f8-5bd41e835a06',
#   'Versichertennummer': 'NS9641437',
#   'Vorname': 'Käthe',
#   'Nachname': 'Dietz',
#   'Geburtsdatum': datetime.date(2015, 3, 21),
#   'Geschlecht': 'männlich',
#   'Adresse': 'Adriane-Trupp-Gasse 80/53, 56129 Bad Langensalza',
#   'Telefon': '+49(0)9452951978',
#   'Email': 'maelzertilmann@example.com',
#   'Blutgruppe': 'AB+',
#   'Letzer_Besuch': datetime.date(2025, 4, 2),
#   'Hausarzt': 'Bernadette Trapp',
#   'Größe_cm': 194,
#   'Gewicht_kg': 84,
#   'Raucher': True,
#   'Allergien': 'keine',
#   'Letzes_EKG': datetime.date(2025, 6, 19),
#   'BMI': 32.5,
#   'Familienstand': 'ledig',
#   'Beruf': 'Informatiker'},
#  {'PatientenID': 'db5e9992-eac3-46dc-9c75-bce46e5a3f6d',
#   'Versichertennummer': 'CO5981350',
#   'Vorname': 'Kazim',
#   'Nachname': 'Rogge',
#   'Geburtsdatum': datetime.date(2007, 11, 21),
#   'Geschlecht': 'männlich',
#   'Adresse': 'Volkhard-Trüb-Gasse 72-17, 29122 Regensburg',
#   'Telefon': '(03053) 49202',
#   'Email': 'linusgeisler@example.net',
#   'Blutgruppe': 'B-',
#   'Letzer_Besuch': datetime.date(2025, 3, 31),
#   'Hausarzt': 'Alfonso Langern',
#   'Größe_cm': 189,
#   'Gewicht_kg': 83,
#   'Raucher': True,
#   'Allergien': 'Milch',
#   'Letzes_EKG': datetime.date(2025, 4, 19),
#   'BMI': 23.9,
#   'Familienstand': 'verheiratet',
#   'Beruf': 'Pilot'},
#  {'PatientenID': '8f70b024-1bde-4d27-9b58-cbff4fc5a613',
#   'Versichertennummer': 'JV5170192',
#   'Vorname': 'Torsten',
#   'Nachname': 'Schwital',
#   'Geburtsdatum': datetime.date(1981, 6, 2),
#   'Geschlecht': 'divers',
#   'Adresse': 'Karlfried-Ritter-Straße 61/95, 62483 Bitterfeld',
#   'Telefon': '(02326) 656887',
#   'Email': 'cgirschner@example.com',
#   'Blutgruppe': 'A+',
#   'Letzer_Besuch': datetime.date(2025, 7, 15),
#   'Hausarzt': 'Irene Zorbach',
#   'Größe_cm': 194,
#   'Gewicht_kg': 59,
#   'Raucher': True,
#   'Allergien': 'Nüsse',
#   'Letzes_EKG': datetime.date(2025, 2, 12),
#   'BMI': 31.1,
#   'Familienstand': 'geschieden',
#   'Beruf': 'Fachinformatiker'},
#  {'PatientenID': '81c6c9e5-1f08-4dad-9376-163fe7f072e5',
#   'Versichertennummer': 'OE8035860',
#   'Vorname': 'Berthold',
#   'Nachname': 'Liebelt',
#   'Geburtsdatum': datetime.date(1992, 2, 19),
#   'Geschlecht': 'weiblich',
#   'Adresse': 'Mülichenstraße 45, 81212 Neubrandenburg',
#   'Telefon': '(02870) 62814',
#   'Email': 'rolf52@example.org',
#   'Blutgruppe': 'B+',
#   'Letzer_Besuch': datetime.date(2025, 7, 25),
#   'Hausarzt': 'Heinz-Günter Henck',
#   'Größe_cm': 181,
#   'Gewicht_kg': 111,
#   'Raucher': False,
#   'Allergien': 'Gluten',
#   'Letzes_EKG': datetime.date(2025, 4, 2),
#   'BMI': 26.8,
#   'Familienstand': 'verheiratet',
#   'Beruf': 'Beamter'},
#  {'PatientenID': '7d360054-e350-4faf-ba50-5a1288542619',
#   'Versichertennummer': 'QZ1579137',
#   'Vorname': 'Emine',
#   'Nachname': 'Junk',
#   'Geburtsdatum': datetime.date(2015, 6, 10),
#   'Geschlecht': 'divers',
#   'Adresse': 'Nora-Holt-Ring 46/53, 35942 Parchim',
#   'Telefon': '+49(0)3529 181494',
#   'Email': 'zstadelmann@example.net',
#   'Blutgruppe': 'O+',
#   'Letzer_Besuch': datetime.date(2025, 5, 18),
#   'Hausarzt': 'Harm Gumprich',
#   'Größe_cm': 175,
#   'Gewicht_kg': 70,
#   'Raucher': True,
#   'Allergien': 'Nüsse',
#   'Letzes_EKG': datetime.date(2025, 3, 9),
#   'BMI': 29.1,
#   'Familienstand': 'geschieden',
#   'Beruf': 'Mechaniker'},
#  {'PatientenID': 'b7579515-5c2c-4a9f-8feb-78d1e1fac657',
#   'Versichertennummer': 'AD9820673',
#   'Vorname': 'Magnus',
#   'Nachname': 'Textor',
#   'Geburtsdatum': datetime.date(1927, 12, 11),
#   'Geschlecht': 'divers',
#   'Adresse': 'Södinggasse 16, 25207 Duderstadt',
#   'Telefon': '(07267) 71295',
#   'Email': 'scheelannelise@example.com',
#   'Blutgruppe': 'A+',
#   'Letzer_Besuch': datetime.date(2025, 1, 13),
#   'Hausarzt': 'Kordula Täsche',
#   'Größe_cm': 201,
#   'Gewicht_kg': 110,
#   'Raucher': False,
#   'Allergien': 'Milch',
#   'Letzes_EKG': datetime.date(2025, 4, 5),
#   'BMI': 20.8,
#   'Familienstand': 'ledig',
#   'Beruf': 'Artist'},
#  {'PatientenID': '215ce051-7960-4f1f-b823-493381dad57b',
#   'Versichertennummer': 'VJ6329896',
#   'Vorname': 'Henriette',
#   'Nachname': 'Oderwald',
#   'Geburtsdatum': datetime.date(2018, 11, 6),
#   'Geschlecht': 'männlich',
#   'Adresse': 'Kraushaarplatz 15-65, 18087 Kelheim',
#   'Telefon': '+49(0)2510 092880',
#   'Email': 'buchholzernestine@example.net',
#   'Blutgruppe': 'A-',
#   'Letzer_Besuch': datetime.date(2025, 3, 17),
#   'Hausarzt': 'Ramazan Ullmann',
#   'Größe_cm': 193,
#   'Gewicht_kg': 122,
#   'Raucher': True,
#   'Allergien': 'Pollen',
#   'Letzes_EKG': datetime.date(2025, 1, 17),
#   'BMI': 20.3,
#   'Familienstand': 'verheiratet',
#   'Beruf': 'Elektroniker'},
#  {'PatientenID': '7a4da7f2-062c-4d1a-9c99-bb9c560edd3d',
#   'Versichertennummer': 'IU0320970',
#   'Vorname': 'Silva',
#   'Nachname': 'Bolnbach',
#   'Geburtsdatum': datetime.date(1949, 11, 3),
#   'Geschlecht': 'weiblich',
#   'Adresse': 'Huhngasse 4/6, 32714 Coburg',
#   'Telefon': '0216492076',
#   'Email': 'polina43@example.net',
#   'Blutgruppe': 'A+',
#   'Letzer_Besuch': datetime.date(2025, 4, 29),
#   'Hausarzt': 'Athanasios Zorbach',
#   'Größe_cm': 170,
#   'Gewicht_kg': 66,
#   'Raucher': False,
#   'Allergien': 'keine',
#   'Letzes_EKG': datetime.date(2025, 5, 21),
#   'BMI': 24.2,
#   'Familienstand': 'ledig',
#   'Beruf': 'Pfleger'},
#  {'PatientenID': '199e4110-8fdd-486a-87eb-84c84bae1c90',
#   'Versichertennummer': 'FM1272470',
#   'Vorname': 'Inka',
#   'Nachname': 'Ladeck',
#   'Geburtsdatum': datetime.date(1962, 9, 11),
#   'Geschlecht': 'divers',
#   'Adresse': 'Salzring 92, 20781 Mühlhausen',
#   'Telefon': '+49(0)4990856590',
#   'Email': 'utz61@example.net',
#   'Blutgruppe': 'AB+',
#   'Letzer_Besuch': datetime.date(2025, 5, 9),
#   'Hausarzt': 'Bekir Rohleder',
#   'Größe_cm': 170,
#   'Gewicht_kg': 63,
#   'Raucher': False,
#   'Allergien': 'Nüsse',
#   'Letzes_EKG': datetime.date(2025, 2, 12),
#   'BMI': 26.4,
#   'Familienstand': 'ledig',
#   'Beruf': 'Beamter'},
#  {'PatientenID': '84312496-5edf-41d0-b9b6-eb5737bff66f',
#   'Versichertennummer': 'WK6062172',
#   'Vorname': 'Mirella',
#   'Nachname': 'Segebahn',
#   'Geburtsdatum': datetime.date(1969, 11, 24),
#   'Geschlecht': 'weiblich',
#   'Adresse': 'Walburga-Döring-Weg 743, 10568 Wittstock',
#   'Telefon': '+49(0) 902883945',
#   'Email': 'wirthchrista-maria@example.com',
#   'Blutgruppe': 'A-',
#   'Letzer_Besuch': datetime.date(2025, 3, 9),
#   'Hausarzt': 'Hugo Briemer',
#   'Größe_cm': 161,
#   'Gewicht_kg': 44,
#   'Raucher': True,
#   'Allergien': 'Milch',
#   'Letzes_EKG': datetime.date(2025, 1, 13),
#   'BMI': 18.9,
#   'Familienstand': 'verheiratet',
#   'Beruf': 'Ausbaufacharbeiter'},
#  {'PatientenID': '37144cd9-4897-44c0-b0a3-18f4389fd93e',
#   'Versichertennummer': 'UY6806995',
#   'Vorname': 'Steffi',
#   'Nachname': 'Wohlgemut',
#   'Geburtsdatum': datetime.date(1943, 1, 30),
#   'Geschlecht': 'weiblich',
#   'Adresse': 'Nada-Rust-Ring 12-47, 31149 Viechtach',
#   'Telefon': '04249 479120',
#   'Email': 'roman42@example.com',
#   'Blutgruppe': 'AB+',
#   'Letzer_Besuch': datetime.date(2025, 2, 6),
#   'Hausarzt': 'Adrian Hesse',
#   'Größe_cm': 191,
#   'Gewicht_kg': 115,
#   'Raucher': False,
#   'Allergien': 'Pollen',
#   'Letzes_EKG': datetime.date(2025, 6, 6),
#   'BMI': 33.2,
#   'Familienstand': 'ledig',
#   'Beruf': 'Drogist'},
#  {'PatientenID': '479804cd-a508-413b-bd80-418ad58a023a',
#   'Versichertennummer': 'DW0907725',
#   'Vorname': 'Martina',
#   'Nachname': 'Schwital',
#   'Geburtsdatum': datetime.date(1926, 2, 19),
#   'Geschlecht': 'weiblich',
#   'Adresse': 'Weinholdweg 8-9, 66472 Ebern',
#   'Telefon': '06619813795',
#   'Email': 'qfroehlich@example.org',
#   'Blutgruppe': 'O-',
#   'Letzer_Besuch': datetime.date(2025, 4, 1),
#   'Hausarzt': 'Fedor Höfig',
#   'Größe_cm': 204,
#   'Gewicht_kg': 67,
#   'Raucher': True,
#   'Allergien': 'keine',
#   'Letzes_EKG': datetime.date(2025, 3, 13),
#   'BMI': 25.6,
#   'Familienstand': 'verheiratet',
#   'Beruf': 'Friseur'},
#  {'PatientenID': '61db8cf1-19da-4a56-922f-cd9acdb3fae0',
#   'Versichertennummer': 'EQ1649940',
#   'Vorname': 'Caroline',
#   'Nachname': 'Rogner',
#   'Geburtsdatum': datetime.date(1982, 10, 30),
#   'Geschlecht': 'divers',
#   'Adresse': 'Reza-Scholtz-Weg 4/5, 62695 Ebern',
#   'Telefon': '03439 66283',
#   'Email': 'marija46@example.net',
#   'Blutgruppe': 'AB-',
#   'Letzer_Besuch': datetime.date(2025, 5, 19),
#   'Hausarzt': 'Sandor Ruppersberger',
#   'Größe_cm': 173,
#   'Gewicht_kg': 119,
#   'Raucher': False,
#   'Allergien': 'Nüsse',
#   'Letzes_EKG': datetime.date(2025, 3, 22),
#   'BMI': 35.5,
#   'Familienstand': 'ledig',
#   'Beruf': 'Augenoptiker'},
#  {'PatientenID': '1045ece6-4f93-4cd9-ac90-60ce793b72d4',
#   'Versichertennummer': 'HS4688183',
#   'Vorname': 'Hans-Martin',
#   'Nachname': 'Kensy',
#   'Geburtsdatum': datetime.date(2010, 12, 8),
#   'Geschlecht': 'weiblich',
#   'Adresse': 'Fröhlichstraße 3, 10536 Wunsiedel',
#   'Telefon': '08193 697932',
#   'Email': 'ingrid95@example.com',
#   'Blutgruppe': 'A-',
#   'Letzer_Besuch': datetime.date(2025, 1, 23),
#   'Hausarzt': 'Ismail Cichorius',
#   'Größe_cm': 141,
#   'Gewicht_kg': 57,
#   'Raucher': False,
#   'Allergien': 'Milch',
#   'Letzes_EKG': datetime.date(2025, 1, 31),
#   'BMI': 28.0,
#   'Familienstand': 'verheiratet',
#   'Beruf': 'Asphaltbauer'},
#  {'PatientenID': '8c24fc10-085a-49c6-ba2d-c65d4088cf73',
#   'Versichertennummer': 'IL2343361',
#   'Vorname': 'Natalja',
#   'Nachname': 'Weihmann',
#   'Geburtsdatum': datetime.date(1935, 4, 12),
#   'Geschlecht': 'weiblich',
#   'Adresse': 'Hardy-Girschner-Weg 4239, 67083 Höxter',
#   'Telefon': '00951 81367',
#   'Email': 'sthies@example.net',
#   'Blutgruppe': 'B-',
#   'Letzer_Besuch': datetime.date(2025, 2, 12),
#   'Hausarzt': 'Franz Sorgatz',
#   'Größe_cm': 158,
#   'Gewicht_kg': 64,
#   'Raucher': False,
#   'Allergien': 'Gluten',
#   'Letzes_EKG': datetime.date(2025, 3, 27),
#   'BMI': 22.6,
#   'Familienstand': 'verwitwet',
#   'Beruf': 'Artist'},
#  {'PatientenID': '311daa92-a636-4e52-b38a-e0f4df51bbec',
#   'Versichertennummer': 'DU9214695',
#   'Vorname': 'Wendelin',
#   'Nachname': 'Kobelt',
#   'Geburtsdatum': datetime.date(1975, 2, 25),
#   'Geschlecht': 'männlich',
#   'Adresse': 'Flantzstr. 703, 62312 Bergzabern',
#   'Telefon': '0890098906',
#   'Email': 'cjaekel@example.com',
#   'Blutgruppe': 'B-',
#   'Letzer_Besuch': datetime.date(2025, 7, 22),
#   'Hausarzt': 'Tanja Schuchhardt',
#   'Größe_cm': 178,
#   'Gewicht_kg': 55,
#   'Raucher': True,
#   'Allergien': 'Pollen',
#   'Letzes_EKG': datetime.date(2025, 1, 14),
#   'BMI': 18.7,
#   'Familienstand': 'verwitwet',
#   'Beruf': 'Bäcker'},
#  {'PatientenID': '7c23ba6c-f7fa-41a3-a747-184c036ee69b',
#   'Versichertennummer': 'HA4161746',
#   'Vorname': 'Raymond',
#   'Nachname': 'Eberhardt',
#   'Geburtsdatum': datetime.date(1959, 7, 3),
#   'Geschlecht': 'weiblich',
#   'Adresse': 'Klaus-Ulrich-Barth-Gasse 9, 59054 Calau',
#   'Telefon': '+49 (0) 7169 712681',
#   'Email': 'beiernadia@example.net',
#   'Blutgruppe': 'AB+',
#   'Letzer_Besuch': datetime.date(2025, 1, 2),
#   'Hausarzt': 'Hardy Margraf',
#   'Größe_cm': 186,
#   'Gewicht_kg': 116,
#   'Raucher': False,
#   'Allergien': 'Milch',
#   'Letzes_EKG': datetime.date(2025, 6, 16),
#   'BMI': 18.3,
#   'Familienstand': 'verheiratet',
#   'Beruf': 'Koreanistiker'},
#  {'PatientenID': '06e9edbd-20e5-403b-8ba5-377f10ba2cd3',
#   'Versichertennummer': 'VD9656786',
#   'Vorname': 'Monique',
#   'Nachname': 'Ortmann',
#   'Geburtsdatum': datetime.date(2012, 11, 26),
#   'Geschlecht': 'weiblich',
#   'Adresse': 'Stahrgasse 96-26, 57155 Kassel',
#   'Telefon': '05071567417',
#   'Email': 'hspiess@example.com',
#   'Blutgruppe': 'O+',
#   'Letzer_Besuch': datetime.date(2025, 1, 25),
#   'Hausarzt': 'Herta Hübel',
#   'Größe_cm': 167,
#   'Gewicht_kg': 88,
#   'Raucher': True,
#   'Allergien': 'keine',
#   'Letzes_EKG': datetime.date(2025, 5, 23),
#   'BMI': 28.3,
#   'Familienstand': 'ledig',
#   'Beruf': 'Asphaltbauer'},
#  {'PatientenID': '518027f0-f2a1-4742-a0e5-c0011abd321e',
#   'Versichertennummer': 'XF1148128',
#   'Vorname': 'Bodo',
#   'Nachname': 'Oestrovsky',
#   'Geburtsdatum': datetime.date(2009, 4, 3),
#   'Geschlecht': 'weiblich',
#   'Adresse': 'Tamara-Lehmann-Allee 37, 78098 Wolmirstedt',
#   'Telefon': '06175738037',
#   'Email': 'bjoernjunitz@example.org',
#   'Blutgruppe': 'A+',
#   'Letzer_Besuch': datetime.date(2025, 3, 25),
#   'Hausarzt': 'Rigo Tschentscher',
#   'Größe_cm': 155,
#   'Gewicht_kg': 66,
#   'Raucher': False,
#   'Allergien': 'Nüsse',
#   'Letzes_EKG': datetime.date(2025, 5, 14),
#   'BMI': 28.9,
#   'Familienstand': 'verheiratet',
#   'Beruf': 'Programmierer'},
#  {'PatientenID': 'a202bcb1-951f-47f3-9a2c-c14b3a71f21f',
#   'Versichertennummer': 'GE4219764',
#   'Vorname': 'Sieghard',
#   'Nachname': 'Wiek',
#   'Geburtsdatum': datetime.date(1931, 6, 20),
#   'Geschlecht': 'divers',
#   'Adresse': 'Neuschäferplatz 21/17, 34012 Parsberg',
#   'Telefon': '+49(0)8468 635565',
#   'Email': 'rosa55@example.org',
#   'Blutgruppe': 'B+',
#   'Letzer_Besuch': datetime.date(2025, 6, 7),
#   'Hausarzt': 'Harry Koch',
#   'Größe_cm': 160,
#   'Gewicht_kg': 83,
#   'Raucher': False,
#   'Allergien': 'keine',
#   'Letzes_EKG': datetime.date(2025, 6, 16),
#   'BMI': 27.0,
#   'Familienstand': 'verheiratet',
#   'Beruf': 'Krankenschwester'},
#  {'PatientenID': '9b832488-6157-4d93-a293-c1aa28d34538',
#   'Versichertennummer': 'RI1964027',
#   'Vorname': 'Karl-Josef',
#   'Nachname': 'Bauer',
#   'Geburtsdatum': datetime.date(1995, 9, 20),
#   'Geschlecht': 'männlich',
#   'Adresse': 'Domenico-Sontag-Gasse 298, 10879 Husum',
#   'Telefon': '04179068815',
#   'Email': 'schlosserwieslaw@example.com',
#   'Blutgruppe': 'A+',
#   'Letzer_Besuch': datetime.date(2025, 4, 30),
#   'Hausarzt': 'Camilla Oderwald',
#   'Größe_cm': 193,
#   'Gewicht_kg': 71,
#   'Raucher': True,
#   'Allergien': 'Nüsse',
#   'Letzes_EKG': datetime.date(2025, 7, 23),
#   'BMI': 33.5,
#   'Familienstand': 'verwitwet',
#   'Beruf': 'Krankenschwester'},
#  {'PatientenID': '6b1ef107-3dbb-4d97-bef7-6f292c4d0c1d',
#   'Versichertennummer': 'UQ8986806',
#   'Vorname': 'Sina',
#   'Nachname': 'Stumpf',
#   'Geburtsdatum': datetime.date(1949, 12, 9),
#   'Geschlecht': 'weiblich',
#   'Adresse': 'Jasmina-Roskoth-Allee 9414, 64255 Koblenz',
#   'Telefon': '05374 59310',
#   'Email': 'ihentschel@example.com',
#   'Blutgruppe': 'B-',
#   'Letzer_Besuch': datetime.date(2025, 6, 25),
#   'Hausarzt': 'Andreas Otto',
#   'Größe_cm': 150,
#   'Gewicht_kg': 102,
#   'Raucher': False,
#   'Allergien': 'Nüsse',
#   'Letzes_EKG': datetime.date(2025, 2, 3),
#   'BMI': 21.2,
#   'Familienstand': 'verheiratet',
#   'Beruf': 'Polizist'},
#  {'PatientenID': '89003dc1-7240-41a8-be7e-49e1271ef859',
#   'Versichertennummer': 'LE0378863',
#   'Vorname': 'Sylvio',
#   'Nachname': 'Heinrich',
#   'Geburtsdatum': datetime.date(1929, 11, 23),
#   'Geschlecht': 'weiblich',
#   'Adresse': 'Neureuthergasse 19/31, 25445 Sulzbach-Rosenberg',
#   'Telefon': '(02264) 44302',
#   'Email': 'william89@example.net',
#   'Blutgruppe': 'AB+',
#   'Letzer_Besuch': datetime.date(2025, 6, 23),
#   'Hausarzt': 'Meik Hornich',
#   'Größe_cm': 140,
#   'Gewicht_kg': 72,
#   'Raucher': False,
#   'Allergien': 'Pollen',
#   'Letzes_EKG': datetime.date(2025, 5, 14),
#   'BMI': 35.9,
#   'Familienstand': 'geschieden',
#   'Beruf': 'Pfleger'},
#  {'PatientenID': '8d09571d-43e5-40ca-9dff-7d2b279c072b',
#   'Versichertennummer': 'TT7597298',
#   'Vorname': 'Slavko',
#   'Nachname': 'Wulff',
#   'Geburtsdatum': datetime.date(1977, 4, 9),
#   'Geschlecht': 'divers',
#   'Adresse': 'Eugen-Weller-Allee 57, 34472 Greiz',
#   'Telefon': '+49(0)2118 097550',
#   'Email': 'gutedogan@example.org',
#   'Blutgruppe': 'O+',
#   'Letzer_Besuch': datetime.date(2025, 3, 20),
#   'Hausarzt': 'Pius Weimer',
#   'Größe_cm': 209,
#   'Gewicht_kg': 52,
#   'Raucher': True,
#   'Allergien': 'Gluten',
#   'Letzes_EKG': datetime.date(2025, 3, 22),
#   'BMI': 27.8,
#   'Familienstand': 'verwitwet',
#   'Beruf': 'Mechaniker'},
#  {'PatientenID': 'adfffe4b-0b08-4ecc-bc2e-ca1c2186b685',
#   'Versichertennummer': 'KF4909974',
#   'Vorname': 'Lothar',
#   'Nachname': 'Eberth',
#   'Geburtsdatum': datetime.date(1992, 8, 20),
#   'Geschlecht': 'weiblich',
#   'Adresse': 'Dorothea-Fischer-Weg 546, 58867 Bernburg',
#   'Telefon': '0714475275',
#   'Email': 'rgude@example.net',
#   'Blutgruppe': 'B+',
#   'Letzer_Besuch': datetime.date(2025, 4, 12),
#   'Hausarzt': 'Heino Bohnbach',
#   'Größe_cm': 161,
#   'Gewicht_kg': 119,
#   'Raucher': False,
#   'Allergien': 'Milch',
#   'Letzes_EKG': datetime.date(2025, 1, 28),
#   'BMI': 27.2,
#   'Familienstand': 'geschieden',
#   'Beruf': 'Artist'},
#  {'PatientenID': '5b5b80ee-b7a5-423c-bcbd-5654008271b5',
#   'Versichertennummer': 'ZF3770270',
#   'Vorname': 'Valentin',
#   'Nachname': 'Karge',
#   'Geburtsdatum': datetime.date(2022, 4, 17),
#   'Geschlecht': 'weiblich',
#   'Adresse': 'Reimund-Dietz-Ring 8/9, 28620 Werdau',
#   'Telefon': '(06643) 855988',
#   'Email': 'sahinhethur@example.com',
#   'Blutgruppe': 'AB-',
#   'Letzer_Besuch': datetime.date(2025, 2, 17),
#   'Hausarzt': 'Remo Benthin',
#   'Größe_cm': 194,
#   'Gewicht_kg': 90,
#   'Raucher': False,
#   'Allergien': 'keine',
#   'Letzes_EKG': datetime.date(2025, 6, 23),
#   'BMI': 26.4,
#   'Familienstand': 'verheiratet',
#   'Beruf': 'Florist'},
#  {'PatientenID': '8f116e7c-5258-4883-88b5-d0bcf3f2c688',
#   'Versichertennummer': 'ZX8424411',
#   'Vorname': 'Reni',
#   'Nachname': 'Häring',
#   'Geburtsdatum': datetime.date(1961, 3, 13),
#   'Geschlecht': 'weiblich',
#   'Adresse': 'Karola-Ortmann-Allee 5695, 00657 Oberviechtach',
#   'Telefon': '(05805) 47608',
#   'Email': 'alwinschacht@example.com',
#   'Blutgruppe': 'A-',
#   'Letzer_Besuch': datetime.date(2025, 5, 17),
#   'Hausarzt': 'Siegmund Beckmann',
#   'Größe_cm': 185,
#   'Gewicht_kg': 66,
#   'Raucher': False,
#   'Allergien': 'Nüsse',
#   'Letzes_EKG': datetime.date(2025, 6, 7),
#   'BMI': 27.7,
#   'Familienstand': 'verwitwet',
#   'Beruf': 'Krankenschwester'},
#  {'PatientenID': 'a52a6026-22d5-49bc-891c-cd56b10acb9a',
#   'Versichertennummer': 'CO9298090',
#   'Vorname': 'Heinz-Dieter',
#   'Nachname': 'Boucsein',
#   'Geburtsdatum': datetime.date(1927, 11, 7),
#   'Geschlecht': 'männlich',
#   'Adresse': 'Heringstr. 16, 59335 Mettmann',
#   'Telefon': '(09554) 73920',
#   'Email': 'sepp77@example.com',
#   'Blutgruppe': 'B+',
#   'Letzer_Besuch': datetime.date(2025, 4, 25),
#   'Hausarzt': 'Irmtrud Pechel',
#   'Größe_cm': 201,
#   'Gewicht_kg': 107,
#   'Raucher': False,
#   'Allergien': 'Milch',
#   'Letzes_EKG': datetime.date(2025, 7, 2),
#   'BMI': 23.7,
#   'Familienstand': 'geschieden',
#   'Beruf': 'Friseur'},
#  {'PatientenID': '3d261985-bce4-4a62-b479-6b7de46dc2e7',
#   'Versichertennummer': 'WN6590387',
#   'Vorname': 'Milena',
#   'Nachname': 'Budig',
#   'Geburtsdatum': datetime.date(1945, 3, 2),
#   'Geschlecht': 'divers',
#   'Adresse': 'Bolzmannweg 8-6, 32771 Rastatt',
#   'Telefon': '+49(0)9164308377',
#   'Email': 'kramerkazim@example.net',
#   'Blutgruppe': 'B-',
#   'Letzer_Besuch': datetime.date(2025, 7, 29),
#   'Hausarzt': 'Jerzy Zirme',
#   'Größe_cm': 217,
#   'Gewicht_kg': 43,
#   'Raucher': False,
#   'Allergien': 'Nüsse',
#   'Letzes_EKG': datetime.date(2025, 3, 4),
#   'BMI': 19.2,
#   'Familienstand': 'ledig',
#   'Beruf': 'Friseur'},
#  {'PatientenID': '1c25fc22-698f-428f-9f69-70e3b7958bad',
#   'Versichertennummer': 'WF1484277',
#   'Vorname': 'Bartholomäus',
#   'Nachname': 'Eimer',
#   'Geburtsdatum': datetime.date(2022, 4, 5),
#   'Geschlecht': 'divers',
#   'Adresse': 'Hoffmannallee 51, 16597 Biedenkopf',
#   'Telefon': '02037504354',
#   'Email': 'mmies@example.com',
#   'Blutgruppe': 'B-',
#   'Letzer_Besuch': datetime.date(2025, 4, 13),
#   'Hausarzt': 'Franca Ullmann',
#   'Größe_cm': 177,
#   'Gewicht_kg': 66,
#   'Raucher': True,
#   'Allergien': 'Nüsse',
#   'Letzes_EKG': datetime.date(2025, 4, 21),
#   'BMI': 25.7,
#   'Familienstand': 'verheiratet',
#   'Beruf': 'Arzt'},
#  {'PatientenID': '112125f0-bcd0-42ea-8966-04d5cddb7370',
#   'Versichertennummer': 'MJ8126772',
#   'Vorname': 'Jerzy',
#   'Nachname': 'Pohl',
#   'Geburtsdatum': datetime.date(1935, 6, 1),
#   'Geschlecht': 'männlich',
#   'Adresse': 'Haufferweg 70/50, 80926 Wanzleben',
#   'Telefon': '+49(0)6720 85771',
#   'Email': 'preisstheobald@example.com',
#   'Blutgruppe': 'B-',
#   'Letzer_Besuch': datetime.date(2025, 2, 26),
#   'Hausarzt': 'Magret Etzold',
#   'Größe_cm': 163,
#   'Gewicht_kg': 99,
#   'Raucher': False,
#   'Allergien': 'Pollen',
#   'Letzes_EKG': datetime.date(2025, 7, 13),
#   'BMI': 29.5,
#   'Familienstand': 'verwitwet',
#   'Beruf': 'Schornsteinfeger'},
#  {'PatientenID': 'cc3a41ec-a0fc-463d-a008-ff9dd8b576c2',
#   'Versichertennummer': 'OI7518135',
#   'Vorname': 'Sara',
#   'Nachname': 'Kambs',
#   'Geburtsdatum': datetime.date(2016, 2, 7),
#   'Geschlecht': 'weiblich',
#   'Adresse': 'Schollallee 23-50, 72350 Grevesmühlen',
#   'Telefon': '+49(0)1477 38530',
#   'Email': 'mariolahuhn@example.net',
#   'Blutgruppe': 'B-',
#   'Letzer_Besuch': datetime.date(2025, 2, 28),
#   'Hausarzt': 'Danica Gnatz',
#   'Größe_cm': 157,
#   'Gewicht_kg': 74,
#   'Raucher': True,
#   'Allergien': 'keine',
#   'Letzes_EKG': datetime.date(2025, 6, 18),
#   'BMI': 34.1,
#   'Familienstand': 'verwitwet',
#   'Beruf': 'Forstwirt'},
#  {'PatientenID': '01cf4e76-fdd2-418b-8947-2e16f0a53e7a',
#   'Versichertennummer': 'QA8583911',
#   'Vorname': 'Katrin',
#   'Nachname': 'Jäntsch',
#   'Geburtsdatum': datetime.date(1960, 2, 3),
#   'Geschlecht': 'männlich',
#   'Adresse': 'Heidemarie-Kühnert-Straße 75/20, 34567 Stollberg',
#   'Telefon': '+49 (0) 2172 569255',
#   'Email': 'cschacht@example.com',
#   'Blutgruppe': 'A-',
#   'Letzer_Besuch': datetime.date(2025, 6, 15),
#   'Hausarzt': 'Agathe Speer',
#   'Größe_cm': 217,
#   'Gewicht_kg': 63,
#   'Raucher': True,
#   'Allergien': 'keine',
#   'Letzes_EKG': datetime.date(2025, 3, 8),
#   'BMI': 26.8,
#   'Familienstand': 'ledig',
#   'Beruf': 'Bankkaufmann'},
#  {'PatientenID': 'd1a577be-00e9-48dd-8dc6-d00040d056fd',
#   'Versichertennummer': 'IK5502948',
#   'Vorname': 'Nicolas',
#   'Nachname': 'Jungfer',
#   'Geburtsdatum': datetime.date(2016, 9, 8),
#   'Geschlecht': 'weiblich',
#   'Adresse': 'Filiz-Schottin-Straße 7312, 65518 Malchin',
#   'Telefon': '02681 13917',
#   'Email': 'thanelilka@example.com',
#   'Blutgruppe': 'O+',
#   'Letzer_Besuch': datetime.date(2025, 6, 6),
#   'Hausarzt': 'German Holt',
#   'Größe_cm': 212,
#   'Gewicht_kg': 73,
#   'Raucher': False,
#   'Allergien': 'keine',
#   'Letzes_EKG': datetime.date(2025, 2, 16),
#   'BMI': 30.7,
#   'Familienstand': 'verheiratet',
#   'Beruf': 'Bankkaufmann'},
#  {'PatientenID': 'e244fad5-522a-42ee-8e8d-2d7faa2a1b4a',
#   'Versichertennummer': 'BG1351695',
#   'Vorname': 'Ingrid',
#   'Nachname': 'Beer',
#   'Geburtsdatum': datetime.date(1953, 7, 8),
#   'Geschlecht': 'männlich',
#   'Adresse': 'Henschelstr. 8, 00300 Suhl',
#   'Telefon': '+49 (0) 0257 208625',
#   'Email': 'robby43@example.net',
#   'Blutgruppe': 'O+',
#   'Letzer_Besuch': datetime.date(2025, 3, 16),
#   'Hausarzt': 'Amanda Roskoth',
#   'Größe_cm': 142,
#   'Gewicht_kg': 47,
#   'Raucher': True,
#   'Allergien': 'Pollen',
#   'Letzes_EKG': datetime.date(2025, 5, 1),
#   'BMI': 32.9,
#   'Familienstand': 'verwitwet',
#   'Beruf': 'Elektroniker'},
#  {'PatientenID': '5f7b3af1-ff1a-4f37-a93b-847250e1430e',
#   'Versichertennummer': 'QV8986512',
#   'Vorname': 'Nelly',
#   'Nachname': 'Etzold',
#   'Geburtsdatum': datetime.date(1981, 11, 9),
#   'Geschlecht': 'divers',
#   'Adresse': 'Ilhan-Seifert-Straße 267, 32072 Hansestadttralsund',
#   'Telefon': '(06910) 717356',
#   'Email': 'margrit90@example.net',
#   'Blutgruppe': 'A+',
#   'Letzer_Besuch': datetime.date(2025, 7, 3),
#   'Hausarzt': 'Heinz-Walter Schenk',
#   'Größe_cm': 194,
#   'Gewicht_kg': 63,
#   'Raucher': False,
#   'Allergien': 'Pollen',
#   'Letzes_EKG': datetime.date(2025, 5, 25),
#   'BMI': 20.5,
#   'Familienstand': 'geschieden',
#   'Beruf': 'Erzieher'},
#  {'PatientenID': '3b9a256e-769c-45b9-83bf-fe45eae3d94a',
#   'Versichertennummer': 'EB5710759',
#   'Vorname': 'Claus-Peter',
#   'Nachname': 'Hahn',
#   'Geburtsdatum': datetime.date(1962, 10, 3),
#   'Geschlecht': 'divers',
#   'Adresse': 'Spießstraße 6/5, 48769 Mühldorf am Inn',
#   'Telefon': '+49(0)9179 922799',
#   'Email': 'charlesgeissler@example.net',
#   'Blutgruppe': 'O-',
#   'Letzer_Besuch': datetime.date(2025, 2, 18),
#   'Hausarzt': 'Henrike Nerger',
#   'Größe_cm': 198,
#   'Gewicht_kg': 117,
#   'Raucher': False,
#   'Allergien': 'keine',
#   'Letzes_EKG': datetime.date(2025, 2, 1),
#   'BMI': 19.5,
#   'Familienstand': 'ledig',
#   'Beruf': 'Krankenschwester'},
#  {'PatientenID': '7572ff2f-5c0d-4087-a7d6-8f51cd56d7bb',
#   'Versichertennummer': 'ZR4194168',
#   'Vorname': 'Ruthild',
#   'Nachname': 'Fröhlich',
#   'Geburtsdatum': datetime.date(2007, 6, 29),
#   'Geschlecht': 'männlich',
#   'Adresse': 'Ziegertallee 84-30, 40835 Starnberg',
#   'Telefon': '+49 (0) 3372 857066',
#   'Email': 'jhornig@example.net',
#   'Blutgruppe': 'O+',
#   'Letzer_Besuch': datetime.date(2025, 7, 15),
#   'Hausarzt': 'Zeki Rohleder',
#   'Größe_cm': 214,
#   'Gewicht_kg': 103,
#   'Raucher': True,
#   'Allergien': 'Milch',
#   'Letzes_EKG': datetime.date(2025, 7, 17),
#   'BMI': 21.6,
#   'Familienstand': 'geschieden',
#   'Beruf': 'Bankkaufmann'},
#  {'PatientenID': 'dbf60864-8a87-4956-b046-f8b958e44f48',
#   'Versichertennummer': 'IC2267212',
#   'Vorname': 'Magnus',
#   'Nachname': 'Buchholz',
#   'Geburtsdatum': datetime.date(2022, 8, 8),
#   'Geschlecht': 'männlich',
#   'Adresse': 'Abdul-Thies-Allee 7-4, 92753 Herford',
#   'Telefon': '+49 (0) 7836 098322',
#   'Email': 'groettneraenne@example.net',
#   'Blutgruppe': 'B-',
#   'Letzer_Besuch': datetime.date(2025, 2, 3),
#   'Hausarzt': 'Monja Müller',
#   'Größe_cm': 182,
#   'Gewicht_kg': 93,
#   'Raucher': True,
#   'Allergien': 'keine',
#   'Letzes_EKG': datetime.date(2025, 5, 23),
#   'BMI': 20.4,
#   'Familienstand': 'ledig',
#   'Beruf': 'Chirurgiemechaniker'},
#  {'PatientenID': '1bccf053-7f2c-461c-84c2-42ae1fb3e4b1',
#   'Versichertennummer': 'ZO4833236',
#   'Vorname': 'Berndt',
#   'Nachname': 'Kusch',
#   'Geburtsdatum': datetime.date(2016, 3, 14),
#   'Geschlecht': 'divers',
#   'Adresse': 'Thanelstr. 83/85, 30370 Lüdinghausen',
#   'Telefon': '+49(0)1987 268197',
#   'Email': 'agnesmoechlichen@example.net',
#   'Blutgruppe': 'O+',
#   'Letzer_Besuch': datetime.date(2025, 5, 28),
#   'Hausarzt': 'Albert Scholz',
#   'Größe_cm': 205,
#   'Gewicht_kg': 75,
#   'Raucher': True,
#   'Allergien': 'Milch',
#   'Letzes_EKG': datetime.date(2025, 1, 27),
#   'BMI': 35.5,
#   'Familienstand': 'ledig',
#   'Beruf': 'Fleischer'},
#  {'PatientenID': 'f5d4cf08-4b64-4b71-ae60-ed3412dc0bef',
#   'Versichertennummer': 'IO3757096',
#   'Vorname': 'Milka',
#   'Nachname': 'Noack',
#   'Geburtsdatum': datetime.date(1991, 3, 4),
#   'Geschlecht': 'männlich',
#   'Adresse': 'Kreuselweg 35-45, 12207 Heiligenstadt',
#   'Telefon': '(08691) 262809',
#   'Email': 'horst-peter50@example.com',
#   'Blutgruppe': 'B-',
#   'Letzer_Besuch': datetime.date(2025, 2, 20),
#   'Hausarzt': 'Susi Hornig',
#   'Größe_cm': 197,
#   'Gewicht_kg': 57,
#   'Raucher': True,
#   'Allergien': 'Nüsse',
#   'Letzes_EKG': datetime.date(2025, 6, 30),
#   'BMI': 20.0,
#   'Familienstand': 'verheiratet',
#   'Beruf': 'Winzer'},
#  {'PatientenID': '27713389-2091-4350-a7d6-068393b31d2e',
#   'Versichertennummer': 'OU6573650',
#   'Vorname': 'Rose',
#   'Nachname': 'Eimer',
#   'Geburtsdatum': datetime.date(1943, 4, 8),
#   'Geschlecht': 'divers',
#   'Adresse': 'Ljudmila-Bolzmann-Weg 10/69, 46125 Main-Höchst',
#   'Telefon': '+49(0)1450439138',
#   'Email': 'dietrich74@example.org',
#   'Blutgruppe': 'AB-',
#   'Letzer_Besuch': datetime.date(2025, 3, 12),
#   'Hausarzt': 'Karl Ruppersberger',
#   'Größe_cm': 204,
#   'Gewicht_kg': 68,
#   'Raucher': True,
#   'Allergien': 'Pollen',
#   'Letzes_EKG': datetime.date(2025, 6, 13),
#   'BMI': 18.2,
#   'Familienstand': 'geschieden',
#   'Beruf': 'Artist'},
#  {'PatientenID': '6de5497c-2c8c-4639-b395-59ae9f69fa9a',
#   'Versichertennummer': 'UW2953389',
#   'Vorname': 'Wojciech',
#   'Nachname': 'Margraf',
#   'Geburtsdatum': datetime.date(1934, 9, 2),
#   'Geschlecht': 'männlich',
#   'Adresse': 'Fabian-Albers-Weg 68/89, 62487 Augsburg',
#   'Telefon': '(01285) 21308',
#   'Email': 'krebsdenny@example.net',
#   'Blutgruppe': 'A+',
#   'Letzer_Besuch': datetime.date(2025, 1, 28),
#   'Hausarzt': 'Ana Karz',
#   'Größe_cm': 156,
#   'Gewicht_kg': 118,
#   'Raucher': True,
#   'Allergien': 'Milch',
#   'Letzes_EKG': datetime.date(2025, 3, 29),
#   'BMI': 34.3,
#   'Familienstand': 'verheiratet',
#   'Beruf': 'Bäcker'},
#  {'PatientenID': '08b6f47e-f8cf-4e9f-bc73-add5aec55680',
#   'Versichertennummer': 'SK2805941',
#   'Vorname': 'Antje',
#   'Nachname': 'Koch',
#   'Geburtsdatum': datetime.date(1948, 6, 10),
#   'Geschlecht': 'weiblich',
#   'Adresse': 'Buchholzallee 7/8, 49529 Forchheim',
#   'Telefon': '(07012) 513720',
#   'Email': 'christelrohleder@example.net',
#   'Blutgruppe': 'A-',
#   'Letzer_Besuch': datetime.date(2025, 7, 15),
#   'Hausarzt': 'Mona Seifert',
#   'Größe_cm': 141,
#   'Gewicht_kg': 126,
#   'Raucher': False,
#   'Allergien': 'Nüsse',
#   'Letzes_EKG': datetime.date(2025, 6, 18),
#   'BMI': 22.1,
#   'Familienstand': 'verheiratet',
#   'Beruf': 'Asphaltbauer'},
#  {'PatientenID': 'b3b51343-3edc-4d04-8ccf-2ff5db33f96f',
#   'Versichertennummer': 'VT0554334',
#   'Vorname': 'Karoline',
#   'Nachname': 'Patberg',
#   'Geburtsdatum': datetime.date(1977, 8, 17),
#   'Geschlecht': 'divers',
#   'Adresse': 'Margarethe-Schmiedt-Gasse 45, 13798 Bogen',
#   'Telefon': '03097592250',
#   'Email': 'songuel63@example.net',
#   'Blutgruppe': 'A+',
#   'Letzer_Besuch': datetime.date(2025, 5, 11),
#   'Hausarzt': 'Andy Lange',
#   'Größe_cm': 146,
#   'Gewicht_kg': 91,
#   'Raucher': True,
#   'Allergien': 'Gluten',
#   'Letzes_EKG': datetime.date(2025, 1, 25),
#   'BMI': 25.0,
#   'Familienstand': 'geschieden',
#   'Beruf': 'Elektroniker'},
#  {'PatientenID': '3e68eb23-806e-4c5d-8bca-45becb84c377',
#   'Versichertennummer': 'SI2790492',
#   'Vorname': 'Emilie',
#   'Nachname': 'Misicher',
#   'Geburtsdatum': datetime.date(1946, 6, 23),
#   'Geschlecht': 'weiblich',
#   'Adresse': 'Falk-Döring-Weg 1, 35076 Wanzleben',
#   'Telefon': '+49(0)2132990471',
#   'Email': 'athanasiosreinhardt@example.org',
#   'Blutgruppe': 'O-',
#   'Letzer_Besuch': datetime.date(2025, 2, 4),
#   'Hausarzt': 'Wladimir Radisch',
#   'Größe_cm': 220,
#   'Gewicht_kg': 59,
#   'Raucher': True,
#   'Allergien': 'Nüsse',
#   'Letzes_EKG': datetime.date(2025, 3, 4),
#   'BMI': 32.7,
#   'Familienstand': 'ledig',
#   'Beruf': 'Designer'},
#  {'PatientenID': '357e32cb-24c6-4f33-9edf-7a0c4d73aa4e',
#   'Versichertennummer': 'YR8039010',
#   'Vorname': 'Irmengard',
#   'Nachname': 'Drubin',
#   'Geburtsdatum': datetime.date(1946, 7, 26),
#   'Geschlecht': 'weiblich',
#   'Adresse': 'Kostolzinplatz 6/9, 25437 Parsberg',
#   'Telefon': '02986713019',
#   'Email': 'elisabetullrich@example.org',
#   'Blutgruppe': 'B+',
#   'Letzer_Besuch': datetime.date(2025, 4, 21),
#   'Hausarzt': 'Ottokar Rogner',
#   'Größe_cm': 171,
#   'Gewicht_kg': 77,
#   'Raucher': False,
#   'Allergien': 'Milch',
#   'Letzes_EKG': datetime.date(2025, 6, 11),
#   'BMI': 23.7,
#   'Familienstand': 'geschieden',
#   'Beruf': 'Mathematiker'},
#  {'PatientenID': '3b20301f-cc92-4d8f-a903-f8df8a6778d5',
#   'Versichertennummer': 'TW5253565',
#   'Vorname': 'Hubertus',
#   'Nachname': 'Pohl',
#   'Geburtsdatum': datetime.date(1938, 1, 3),
#   'Geschlecht': 'divers',
#   'Adresse': 'Burkhard-Kraus-Allee 1-2, 11004 Bernburg',
#   'Telefon': '0797544815',
#   'Email': 'leopold93@example.com',
#   'Blutgruppe': 'O-',
#   'Letzer_Besuch': datetime.date(2025, 1, 18),
#   'Hausarzt': 'Lene Gierschner',
#   'Größe_cm': 178,
#   'Gewicht_kg': 57,
#   'Raucher': False,
#   'Allergien': 'Milch',
#   'Letzes_EKG': datetime.date(2025, 1, 17),
#   'BMI': 20.9,
#   'Familienstand': 'ledig',
#   'Beruf': 'Pilot'},
#  {'PatientenID': '368b3e46-d49a-4f61-92de-590269ba8485',
#   'Versichertennummer': 'HB1593813',
#   'Vorname': 'Anatoli',
#   'Nachname': 'Anders',
#   'Geburtsdatum': datetime.date(1982, 10, 24),
#   'Geschlecht': 'divers',
#   'Adresse': 'Anneliese-Flantz-Gasse 8/6, 74989 Recklinghausen',
#   'Telefon': '+49 (0) 1895 038952',
#   'Email': 'sergiobluemel@example.net',
#   'Blutgruppe': 'O-',
#   'Letzer_Besuch': datetime.date(2025, 1, 16),
#   'Hausarzt': 'Adina Bohlander',
#   'Größe_cm': 175,
#   'Gewicht_kg': 62,
#   'Raucher': False,
#   'Allergien': 'Pollen',
#   'Letzes_EKG': datetime.date(2025, 7, 26),
#   'BMI': 32.1,
#   'Familienstand': 'verheiratet',
#   'Beruf': 'Altenpfleger'},
#  {'PatientenID': '9d4cab43-a05f-4d42-89c5-dcf73f8abcd1',
#   'Versichertennummer': 'VY8825151',
#   'Vorname': 'Ortwin',
#   'Nachname': 'Dussen van',
#   'Geburtsdatum': datetime.date(1937, 4, 21),
#   'Geschlecht': 'divers',
#   'Adresse': 'Hellwigallee 227, 52558 Zerbst',
#   'Telefon': '0063753375',
#   'Email': 'owarmer@example.net',
#   'Blutgruppe': 'O+',
#   'Letzer_Besuch': datetime.date(2025, 2, 4),
#   'Hausarzt': 'Wilhelmine Dussen van',
#   'Größe_cm': 189,
#   'Gewicht_kg': 99,
#   'Raucher': True,
#   'Allergien': 'Milch',
#   'Letzes_EKG': datetime.date(2025, 4, 10),
#   'BMI': 31.0,
#   'Familienstand': 'ledig',
#   'Beruf': 'Drogist'},
#  {'PatientenID': 'd11bdc4d-a12a-45b4-be19-23c9beed8d02',
#   'Versichertennummer': 'LI5588393',
#   'Vorname': 'Gernot',
#   'Nachname': 'Wähner',
#   'Geburtsdatum': datetime.date(1945, 5, 26),
#   'Geschlecht': 'männlich',
#   'Adresse': 'Marianna-Wiek-Allee 4-2, 77588 Torgau',
#   'Telefon': '(02156) 41696',
#   'Email': 'mustafamans@example.org',
#   'Blutgruppe': 'AB-',
#   'Letzer_Besuch': datetime.date(2025, 4, 27),
#   'Hausarzt': 'Guenther Ziegert',
#   'Größe_cm': 202,
#   'Gewicht_kg': 88,
#   'Raucher': True,
#   'Allergien': 'Milch',
#   'Letzes_EKG': datetime.date(2025, 5, 20),
#   'BMI': 26.3,
#   'Familienstand': 'verwitwet',
#   'Beruf': 'Polizist'},
#  {'PatientenID': '4c3ac47c-9bd5-4b1b-841d-546cd714aa36',
#   'Versichertennummer': 'YS1537554',
#   'Vorname': 'Roy',
#   'Nachname': 'Hornig',
#   'Geburtsdatum': datetime.date(2008, 12, 19),
#   'Geschlecht': 'weiblich',
#   'Adresse': 'Döringring 6, 59120 Eichstätt',
#   'Telefon': '(06252) 06318',
#   'Email': 'catherine38@example.org',
#   'Blutgruppe': 'AB-',
#   'Letzer_Besuch': datetime.date(2025, 6, 10),
#   'Hausarzt': 'Brunhild Mohaupt',
#   'Größe_cm': 195,
#   'Gewicht_kg': 50,
#   'Raucher': False,
#   'Allergien': 'keine',
#   'Letzes_EKG': datetime.date(2025, 5, 21),
#   'BMI': 35.7,
#   'Familienstand': 'verheiratet',
#   'Beruf': 'Erzieher'},
#  {'PatientenID': '3021608a-2bd8-4093-bebe-93f98c4048e3',
#   'Versichertennummer': 'LY5965480',
#   'Vorname': 'Cosima',
#   'Nachname': 'Zahn',
#   'Geburtsdatum': datetime.date(2023, 12, 16),
#   'Geschlecht': 'weiblich',
#   'Adresse': 'Schweitzerring 92, 89866 Badibling',
#   'Telefon': '+49(0)7063 73862',
#   'Email': 'hanife19@example.net',
#   'Blutgruppe': 'B-',
#   'Letzer_Besuch': datetime.date(2025, 1, 15),
#   'Hausarzt': 'Anastasios Ruppert',
#   'Größe_cm': 198,
#   'Gewicht_kg': 108,
#   'Raucher': True,
#   'Allergien': 'Nüsse',
#   'Letzes_EKG': datetime.date(2025, 7, 13),
#   'BMI': 27.1,
#   'Familienstand': 'ledig',
#   'Beruf': 'Drogist'},
#  {'PatientenID': 'eca16fe4-1d85-4eca-9371-d502e774d489',
#   'Versichertennummer': 'ET6222912',
#   'Vorname': 'Hans-Michael',
#   'Nachname': 'Gnatz',
#   'Geburtsdatum': datetime.date(1927, 12, 20),
#   'Geschlecht': 'männlich',
#   'Adresse': 'Winklerweg 10, 07910 Borken',
#   'Telefon': '+49(0)6455539035',
#   'Email': 'langernberthold@example.com',
#   'Blutgruppe': 'B-',
#   'Letzer_Besuch': datetime.date(2025, 3, 24),
#   'Hausarzt': 'Zeki Bärer',
#   'Größe_cm': 178,
#   'Gewicht_kg': 118,
#   'Raucher': False,
#   'Allergien': 'Nüsse',
#   'Letzes_EKG': datetime.date(2025, 3, 23),
#   'BMI': 34.3,
#   'Familienstand': 'geschieden',
#   'Beruf': 'Elektroniker'},
#  {'PatientenID': '797edb27-6ca3-47ec-b4a8-a2f7bb47b91b',
#   'Versichertennummer': 'QC5487993',
#   'Vorname': 'Rolf',
#   'Nachname': 'Henck',
#   'Geburtsdatum': datetime.date(1975, 4, 4),
#   'Geschlecht': 'männlich',
#   'Adresse': 'Gunhild-Etzold-Straße 23/49, 69899 Sonneberg',
#   'Telefon': '05547476147',
#   'Email': 'whoefig@example.net',
#   'Blutgruppe': 'A+',
#   'Letzer_Besuch': datetime.date(2025, 5, 5),
#   'Hausarzt': 'Alexander Fliegner',
#   'Größe_cm': 185,
#   'Gewicht_kg': 41,
#   'Raucher': False,
#   'Allergien': 'Gluten',
#   'Letzes_EKG': datetime.date(2025, 7, 29),
#   'BMI': 27.9,
#   'Familienstand': 'verwitwet',
#   'Beruf': 'Pfleger'},
#  {'PatientenID': 'f4316391-fe64-4fa5-a322-479d821c5f56',
#   'Versichertennummer': 'XQ3811343',
#   'Vorname': 'Adelinde',
#   'Nachname': 'Rosenow',
#   'Geburtsdatum': datetime.date(2011, 2, 9),
#   'Geschlecht': 'divers',
#   'Adresse': 'Eberthweg 3-2, 14144 Melle',
#   'Telefon': '0648334551',
#   'Email': 'kramerolivia@example.org',
#   'Blutgruppe': 'O-',
#   'Letzer_Besuch': datetime.date(2025, 2, 17),
#   'Hausarzt': 'Jörg Schacht',
#   'Größe_cm': 167,
#   'Gewicht_kg': 66,
#   'Raucher': False,
#   'Allergien': 'keine',
#   'Letzes_EKG': datetime.date(2025, 3, 23),
#   'BMI': 19.3,
#   'Familienstand': 'geschieden',
#   'Beruf': 'Programmierer'},
#  {'PatientenID': 'b49ba5ef-16f5-4ca6-8c16-8d3b1bf23329',
#   'Versichertennummer': 'EH2463719',
#   'Vorname': 'Gerard',
#   'Nachname': 'Mielcarek',
#   'Geburtsdatum': datetime.date(2019, 10, 19),
#   'Geschlecht': 'weiblich',
#   'Adresse': 'Eva-Maria-Margraf-Platz 30/22, 70365 Artern',
#   'Telefon': '(02712) 39189',
#   'Email': 'speernadeshda@example.com',
#   'Blutgruppe': 'O-',
#   'Letzer_Besuch': datetime.date(2025, 2, 11),
#   'Hausarzt': 'Athanasios Trubin',
#   'Größe_cm': 207,
#   'Gewicht_kg': 65,
#   'Raucher': False,
#   'Allergien': 'Nüsse',
#   'Letzes_EKG': datetime.date(2025, 5, 30),
#   'BMI': 24.8,
#   'Familienstand': 'verwitwet',
#   'Beruf': 'Winzer'},
#  {'PatientenID': '70159853-08d0-4ec6-be62-78e8fc205560',
#   'Versichertennummer': 'CY1688518',
#   'Vorname': 'Gundi',
#   'Nachname': 'Huhn',
#   'Geburtsdatum': datetime.date(1938, 9, 11),
#   'Geschlecht': 'weiblich',
#   'Adresse': 'Schollstr. 9, 84107 Feuchtwangen',
#   'Telefon': '+49 (0) 9473 135220',
#   'Email': 'roggechristiane@example.net',
#   'Blutgruppe': 'AB-',
#   'Letzer_Besuch': datetime.date(2025, 6, 22),
#   'Hausarzt': 'Konstantinos Schinke',
#   'Größe_cm': 189,
#   'Gewicht_kg': 95,
#   'Raucher': False,
#   'Allergien': 'keine',
#   'Letzes_EKG': datetime.date(2025, 4, 9),
#   'BMI': 21.8,
#   'Familienstand': 'verwitwet',
#   'Beruf': 'Augenoptiker'},
#  {'PatientenID': '75940311-a382-4da3-9de7-86a15c1baa95',
#   'Versichertennummer': 'FU8918645',
#   'Vorname': 'Patric',
#   'Nachname': 'Adolph',
#   'Geburtsdatum': datetime.date(1971, 1, 27),
#   'Geschlecht': 'weiblich',
#   'Adresse': 'Weitzelstr. 4/3, 90271 Waren',
#   'Telefon': '+49(0)5592 46530',
#   'Email': 'ortwin14@example.org',
#   'Blutgruppe': 'AB+',
#   'Letzer_Besuch': datetime.date(2025, 6, 27),
#   'Hausarzt': 'Liselotte Mohaupt',
#   'Größe_cm': 213,
#   'Gewicht_kg': 128,
#   'Raucher': True,
#   'Allergien': 'Pollen',
#   'Letzes_EKG': datetime.date(2025, 4, 14),
#   'BMI': 22.5,
#   'Familienstand': 'ledig',
#   'Beruf': 'Krankenschwester'},
#  {'PatientenID': 'd119291c-df3f-4781-b92c-7381d49381d8',
#   'Versichertennummer': 'SA0345920',
#   'Vorname': 'Lucia',
#   'Nachname': 'Herrmann',
#   'Geburtsdatum': datetime.date(2005, 5, 22),
#   'Geschlecht': 'weiblich',
#   'Adresse': 'Börnerstraße 1727, 29136 Dinslaken',
#   'Telefon': '+49(0) 238238581',
#   'Email': 'rognercord@example.org',
#   'Blutgruppe': 'O-',
#   'Letzer_Besuch': datetime.date(2025, 2, 17),
#   'Hausarzt': 'Karl-Wilhelm Trupp',
#   'Größe_cm': 211,
#   'Gewicht_kg': 128,
#   'Raucher': True,
#   'Allergien': 'Gluten',
#   'Letzes_EKG': datetime.date(2025, 4, 30),
#   'BMI': 22.8,
#   'Familienstand': 'verheiratet',
#   'Beruf': 'Pilot'},
#  {'PatientenID': '3ca1c57f-1174-4c44-9283-3daa89b9e286',
#   'Versichertennummer': 'JI1835775',
#   'Vorname': 'Ekkehart',
#   'Nachname': 'Faust',
#   'Geburtsdatum': datetime.date(1931, 12, 15),
#   'Geschlecht': 'männlich',
#   'Adresse': 'Henschelstraße 2-4, 42428 Hettstedt',
#   'Telefon': '+49(0)3749 16767',
#   'Email': 'lilikoch-ii@example.com',
#   'Blutgruppe': 'AB+',
#   'Letzer_Besuch': datetime.date(2025, 1, 6),
#   'Hausarzt': 'Monica Trubin',
#   'Größe_cm': 217,
#   'Gewicht_kg': 72,
#   'Raucher': False,
#   'Allergien': 'keine',
#   'Letzes_EKG': datetime.date(2025, 7, 18),
#   'BMI': 19.8,
#   'Familienstand': 'ledig',
#   'Beruf': 'Mechaniker'},
#  {'PatientenID': 'b8b57c05-e866-4469-93cd-3b3c4d62faa6',
#   'Versichertennummer': 'PO6698871',
#   'Vorname': 'Nadine',
#   'Nachname': 'Huhn',
#   'Geburtsdatum': datetime.date(1961, 3, 8),
#   'Geschlecht': 'männlich',
#   'Adresse': 'Pieperallee 4, 13819 Hansestadttralsund',
#   'Telefon': '(01765) 53099',
#   'Email': 'katharinafischer@example.net',
#   'Blutgruppe': 'O-',
#   'Letzer_Besuch': datetime.date(2025, 1, 29),
#   'Hausarzt': 'Klaus-Michael Ernst',
#   'Größe_cm': 205,
#   'Gewicht_kg': 68,
#   'Raucher': False,
#   'Allergien': 'Gluten',
#   'Letzes_EKG': datetime.date(2025, 6, 19),
#   'BMI': 32.0,
#   'Familienstand': 'ledig',
#   'Beruf': 'Polizist'},
#  {'PatientenID': 'd177cdce-fa2f-449f-90a7-80029f5cb589',
#   'Versichertennummer': 'ST9866765',
#   'Vorname': 'Kirsten',
#   'Nachname': 'Eberhardt',
#   'Geburtsdatum': datetime.date(1928, 10, 12),
#   'Geschlecht': 'männlich',
#   'Adresse': 'Röhrdanzring 7, 39591 Apolda',
#   'Telefon': '06687 65703',
#   'Email': 'hinrichhaenel@example.net',
#   'Blutgruppe': 'B-',
#   'Letzer_Besuch': datetime.date(2025, 5, 28),
#   'Hausarzt': 'Janus Hertrampf',
#   'Größe_cm': 177,
#   'Gewicht_kg': 103,
#   'Raucher': False,
#   'Allergien': 'Gluten',
#   'Letzes_EKG': datetime.date(2025, 2, 18),
#   'BMI': 30.8,
#   'Familienstand': 'ledig',
#   'Beruf': 'Fachinformatiker'},
#  {'PatientenID': '7efa29f7-ac7f-4a31-b7cc-73bec456740d',
#   'Versichertennummer': 'GG0000913',
#   'Vorname': 'Axel',
# ...
#   'Nachname': 'Rosenow',
#   'Geburtsdatum': datetime.date(2005, 12, 14),
#   'Geschlecht': 'divers',
#   'Adresse': 'Alban-Kallert-Gasse 6-7, 07145 Ravensburg',
#   'Telefon': '+49(0)6482 015237',
#   'Email': 'moritzziegert@example.org',
#   'Blutgruppe': 'B-',
#   'Letzer_Besuch': datetime.date(2025, 6, 22),
#   'Hausarzt': 'Ivan Seifert',
#   'Größe_cm': 154,
#   'Gewicht_kg': 106,
#   'Raucher': False,
#   'Allergien': 'Nüsse',
#   'Letzes_EKG': datetime.date(2025, 6, 2),
#   'BMI': 31.6,
#   'Familienstand': 'verheiratet',
#   'Beruf': 'Chemikant'},
#  {'PatientenID': '18e50fc2-7554-4c1e-9311-c74be3d457dd',
#   'Versichertennummer': 'QW5865375',
#   'Vorname': 'Aloys',
#   'Nachname': 'Hörle',
#   'Geburtsdatum': datetime.date(1972, 3, 11),
#   'Geschlecht': 'divers',
#   'Adresse': 'Blochgasse 40/34, 33457 Kronach',
#   'Telefon': '+49(0)1445 74806',
#   'Email': 'detlef03@example.com',
#   'Blutgruppe': 'AB+',
#   'Letzer_Besuch': datetime.date(2025, 6, 29),
#   'Hausarzt': 'Klaus Dieter Börner',
#   'Größe_cm': 203,
#   'Gewicht_kg': 80,
#   'Raucher': True,
#   'Allergien': 'Pollen',
#   'Letzes_EKG': datetime.date(2025, 2, 19),
#   'BMI': 27.6,
#   'Familienstand': 'ledig',
#   'Beruf': 'Elektroniker'},
#  {'PatientenID': '2ab9fb5f-0a6a-4401-b19e-9c60ee4b4711',
#   'Versichertennummer': 'IS7040299',
#   'Vorname': 'Hellmut',
#   'Nachname': 'Hermann',
#   'Geburtsdatum': datetime.date(2012, 8, 18),
#   'Geschlecht': 'männlich',
#   'Adresse': 'Rosemannring 365, 26393 Weißenfels',
#   'Telefon': '07683 06887',
#   'Email': 'jjaehn@example.net',
#   'Blutgruppe': 'AB-',
#   'Letzer_Besuch': datetime.date(2025, 7, 4),
#   'Hausarzt': 'Hans-Erich Röhricht',
#   'Größe_cm': 180,
#   'Gewicht_kg': 73,
#   'Raucher': False,
#   'Allergien': 'Pollen',
#   'Letzes_EKG': datetime.date(2025, 7, 1),
#   'BMI': 33.6,
#   'Familienstand': 'geschieden',
#   'Beruf': 'Ausbaufacharbeiter'},
#  {'PatientenID': 'ac1a30f7-4e6d-4362-81df-f55c35343f16',
#   'Versichertennummer': 'KC3007292',
#   'Vorname': 'Marietta',
#   'Nachname': 'Meister',
#   'Geburtsdatum': datetime.date(1927, 10, 29),
#   'Geschlecht': 'weiblich',
#   'Adresse': 'Guenter-Weller-Weg 811, 57233 Merseburg',
#   'Telefon': '+49(0)6178 036718',
#   'Email': 'torben32@example.org',
#   'Blutgruppe': 'A-',
#   'Letzer_Besuch': datetime.date(2025, 6, 29),
#   'Hausarzt': 'Ines Briemer',
#   'Größe_cm': 212,
#   'Gewicht_kg': 85,
#   'Raucher': True,
#   'Allergien': 'Nüsse',
#   'Letzes_EKG': datetime.date(2025, 3, 29),
#   'BMI': 24.2,
#   'Familienstand': 'ledig',
#   'Beruf': 'Beamter'},
#  {'PatientenID': '2e51ce1d-a344-4809-97ca-b038cad6641c',
#   'Versichertennummer': 'KV9806633',
#   'Vorname': 'Brigitte',
#   'Nachname': 'Gerlach',
#   'Geburtsdatum': datetime.date(1958, 12, 25),
#   'Geschlecht': 'divers',
#   'Adresse': 'Blanka-Benthin-Allee 48, 51221 Neustadt am Rübenberge',
#   'Telefon': '+49(0)6998 97622',
#   'Email': 'bettijockel@example.com',
#   'Blutgruppe': 'B-',
#   'Letzer_Besuch': datetime.date(2025, 3, 31),
#   'Hausarzt': 'Reinhilde Ebert',
#   'Größe_cm': 192,
#   'Gewicht_kg': 118,
#   'Raucher': True,
#   'Allergien': 'keine',
#   'Letzes_EKG': datetime.date(2025, 1, 20),
#   'BMI': 26.5,
#   'Familienstand': 'ledig',
#   'Beruf': 'Ausbaufacharbeiter'},
#  {'PatientenID': 'd9cf00d5-2abc-4c9a-99e9-36fdf9b820ff',
#   'Versichertennummer': 'VN6987451',
#   'Vorname': 'Adam',
#   'Nachname': 'Hettner',
#   'Geburtsdatum': datetime.date(1940, 10, 25),
#   'Geschlecht': 'männlich',
#   'Adresse': 'Ruppersbergerplatz 601, 41408 Torgau',
#   'Telefon': '+49 (0) 5690 982321',
#   'Email': 'thieshartmann@example.com',
#   'Blutgruppe': 'B+',
#   'Letzer_Besuch': datetime.date(2025, 2, 12),
#   'Hausarzt': 'Ralph Rosemann',
#   'Größe_cm': 191,
#   'Gewicht_kg': 53,
#   'Raucher': False,
#   'Allergien': 'Milch',
#   'Letzes_EKG': datetime.date(2025, 7, 18),
#   'BMI': 25.0,
#   'Familienstand': 'geschieden',
#   'Beruf': 'Winzer'},
#  {'PatientenID': '9466c566-1cd1-46d4-ba11-742aa6728e15',
#   'Versichertennummer': 'FU4512686',
#   'Vorname': 'Sibylle',
#   'Nachname': 'Bohnbach',
#   'Geburtsdatum': datetime.date(1951, 9, 1),
#   'Geschlecht': 'männlich',
#   'Adresse': 'Marie-Therese-Kabus-Straße 6-7, 91734 Sulzbach-Rosenberg',
#   'Telefon': '(07023) 41961',
#   'Email': 'tklotz@example.net',
#   'Blutgruppe': 'A-',
#   'Letzer_Besuch': datetime.date(2025, 7, 6),
#   'Hausarzt': 'Alberto Schönland',
#   'Größe_cm': 166,
#   'Gewicht_kg': 123,
#   'Raucher': False,
#   'Allergien': 'Milch',
#   'Letzes_EKG': datetime.date(2025, 1, 26),
#   'BMI': 27.4,
#   'Familienstand': 'geschieden',
#   'Beruf': 'Fachinformatiker'},
#  {'PatientenID': '98000331-364a-443c-930c-f712f65dd577',
#   'Versichertennummer': 'WD2124609',
#   'Vorname': 'Gisbert',
#   'Nachname': 'Jungfer',
#   'Geburtsdatum': datetime.date(1961, 7, 26),
#   'Geschlecht': 'weiblich',
#   'Adresse': 'Rörrichtstraße 5, 10161 Luckau',
#   'Telefon': '(06944) 29093',
#   'Email': 'gotthardevamaria@example.net',
#   'Blutgruppe': 'AB-',
#   'Letzer_Besuch': datetime.date(2025, 5, 23),
#   'Hausarzt': 'Gabi Pärtzelt',
#   'Größe_cm': 191,
#   'Gewicht_kg': 100,
#   'Raucher': True,
#   'Allergien': 'Pollen',
#   'Letzes_EKG': datetime.date(2025, 2, 8),
#   'BMI': 20.3,
#   'Familienstand': 'verheiratet',
#   'Beruf': 'Elektroniker'},
#  {'PatientenID': 'a9d15991-2375-4c61-93f4-2bcbc951fb07',
#   'Versichertennummer': 'MX3072173',
#   'Vorname': 'Annemarie',
#   'Nachname': 'Gorlitz',
#   'Geburtsdatum': datetime.date(1970, 4, 19),
#   'Geschlecht': 'divers',
#   'Adresse': 'Bettina-Wähner-Weg 23, 97992 Rathenow',
#   'Telefon': '03881 896093',
#   'Email': 'bcaspar@example.net',
#   'Blutgruppe': 'A-',
#   'Letzer_Besuch': datetime.date(2025, 5, 26),
#   'Hausarzt': 'Horst-Peter Graf',
#   'Größe_cm': 161,
#   'Gewicht_kg': 130,
#   'Raucher': True,
#   'Allergien': 'Pollen',
#   'Letzes_EKG': datetime.date(2025, 1, 10),
#   'BMI': 21.2,
#   'Familienstand': 'verheiratet',
#   'Beruf': 'Pilot'},
#  {'PatientenID': 'e61e6faf-d88b-4b58-aab9-15f467979099',
#   'Versichertennummer': 'DH9277399',
#   'Vorname': 'Jessica',
#   'Nachname': 'Bähr',
#   'Geburtsdatum': datetime.date(1973, 4, 26),
#   'Geschlecht': 'weiblich',
#   'Adresse': 'Zeljko-Beyer-Allee 6-3, 10535 Soest',
#   'Telefon': '02449 98132',
#   'Email': 'froehlichralf-peter@example.net',
#   'Blutgruppe': 'A+',
#   'Letzer_Besuch': datetime.date(2025, 7, 9),
#   'Hausarzt': 'Valentin Peukert',
#   'Größe_cm': 186,
#   'Gewicht_kg': 71,
#   'Raucher': False,
#   'Allergien': 'Nüsse',
#   'Letzes_EKG': datetime.date(2025, 6, 12),
#   'BMI': 21.6,
#   'Familienstand': 'verheiratet',
#   'Beruf': 'Fachinformatiker'},
#  {'PatientenID': 'f5fa7623-54ac-4e9b-91b3-025712edb19b',
#   'Versichertennummer': 'QE8811669',
#   'Vorname': 'Achim',
#   'Nachname': 'Stahr',
#   'Geburtsdatum': datetime.date(1967, 11, 23),
#   'Geschlecht': 'divers',
#   'Adresse': 'Boucseingasse 90-24, 47339 Strausberg',
#   'Telefon': '(03592) 32874',
#   'Email': 'jannmoechlichen@example.org',
#   'Blutgruppe': 'B+',
#   'Letzer_Besuch': datetime.date(2025, 5, 9),
#   'Hausarzt': 'Meinolf Hendriks',
#   'Größe_cm': 160,
#   'Gewicht_kg': 65,
#   'Raucher': True,
#   'Allergien': 'Gluten',
#   'Letzes_EKG': datetime.date(2025, 2, 9),
#   'BMI': 32.5,
#   'Familienstand': 'verheiratet',
#   'Beruf': 'Elektroniker'},
#  {'PatientenID': '85b4be5b-0c4d-45e9-9a77-f2d94b50da86',
#   'Versichertennummer': 'BO1624696',
#   'Vorname': 'Katerina',
#   'Nachname': 'Hövel',
#   'Geburtsdatum': datetime.date(1934, 2, 16),
#   'Geschlecht': 'weiblich',
#   'Adresse': 'Fauststraße 58, 27674 Niesky',
#   'Telefon': '05915 26989',
#   'Email': 'rkramer@example.org',
#   'Blutgruppe': 'A-',
#   'Letzer_Besuch': datetime.date(2025, 2, 20),
#   'Hausarzt': 'Antonina Trommler',
#   'Größe_cm': 146,
#   'Gewicht_kg': 129,
#   'Raucher': False,
#   'Allergien': 'Pollen',
#   'Letzes_EKG': datetime.date(2025, 5, 29),
#   'BMI': 30.4,
#   'Familienstand': 'verheiratet',
#   'Beruf': 'Fachinformatiker'},
#  {'PatientenID': 'ef041c91-20b1-4a7b-adf6-92c14cf2d846',
#   'Versichertennummer': 'XU9176629',
#   'Vorname': 'Robby',
#   'Nachname': 'Henck',
#   'Geburtsdatum': datetime.date(1930, 5, 8),
#   'Geschlecht': 'weiblich',
#   'Adresse': 'Etzlerring 58-76, 66060 Königs Wusterhausen',
#   'Telefon': '+49(0)2585 310279',
#   'Email': 'erhardtdippel@example.org',
#   'Blutgruppe': 'AB+',
#   'Letzer_Besuch': datetime.date(2025, 6, 3),
#   'Hausarzt': 'Luzie Kusch',
#   'Größe_cm': 195,
#   'Gewicht_kg': 128,
#   'Raucher': False,
#   'Allergien': 'Pollen',
#   'Letzes_EKG': datetime.date(2025, 7, 7),
#   'BMI': 19.3,
#   'Familienstand': 'verwitwet',
#   'Beruf': 'Polizist'},
#  {'PatientenID': '2e5818da-67ae-47db-90b0-0f936d002ba9',
#   'Versichertennummer': 'WP1813353',
#   'Vorname': 'Centa',
#   'Nachname': 'Bien',
#   'Geburtsdatum': datetime.date(1930, 2, 11),
#   'Geschlecht': 'männlich',
#   'Adresse': 'Baptist-Lange-Ring 64, 31922 Hansestadttralsund',
#   'Telefon': '03329256978',
#   'Email': 'iljakarge@example.com',
#   'Blutgruppe': 'A+',
#   'Letzer_Besuch': datetime.date(2025, 2, 14),
#   'Hausarzt': 'Sylvio Scholz',
#   'Größe_cm': 212,
#   'Gewicht_kg': 109,
#   'Raucher': True,
#   'Allergien': 'Pollen',
#   'Letzes_EKG': datetime.date(2025, 3, 26),
#   'BMI': 28.2,
#   'Familienstand': 'verheiratet',
#   'Beruf': 'Erzieher'},
#  {'PatientenID': '227fdb4b-e9e2-4af2-8cca-5eff4e179f7c',
#   'Versichertennummer': 'ZA9431188',
#   'Vorname': 'Nicolaus',
#   'Nachname': 'Kreusel',
#   'Geburtsdatum': datetime.date(2015, 5, 5),
#   'Geschlecht': 'weiblich',
#   'Adresse': 'Margrit-Wagenknecht-Allee 85-22, 90198 Pfaffenhofen an der Ilm',
#   'Telefon': '+49 (0) 4969 380480',
#   'Email': 'eberthcornelius@example.net',
#   'Blutgruppe': 'A-',
#   'Letzer_Besuch': datetime.date(2025, 4, 25),
#   'Hausarzt': 'Walburga Haase',
#   'Größe_cm': 144,
#   'Gewicht_kg': 60,
#   'Raucher': True,
#   'Allergien': 'keine',
#   'Letzes_EKG': datetime.date(2025, 6, 1),
#   'BMI': 31.9,
#   'Familienstand': 'ledig',
#   'Beruf': 'Designer'},
#  {'PatientenID': 'e3a7f78d-218c-4c31-889b-1e8688cd781e',
#   'Versichertennummer': 'BV2735828',
#   'Vorname': 'Hartmuth',
#   'Nachname': 'Mangold',
#   'Geburtsdatum': datetime.date(1990, 5, 19),
#   'Geschlecht': 'divers',
#   'Adresse': 'Rörrichtstraße 32, 06610 Eckernförde',
#   'Telefon': '+49(0)8260 910013',
#   'Email': 'rosekriemhild@example.com',
#   'Blutgruppe': 'AB-',
#   'Letzer_Besuch': datetime.date(2025, 2, 8),
#   'Hausarzt': 'Torsten Fröhlich',
#   'Größe_cm': 160,
#   'Gewicht_kg': 57,
#   'Raucher': False,
#   'Allergien': 'Milch',
#   'Letzes_EKG': datetime.date(2025, 7, 12),
#   'BMI': 28.6,
#   'Familienstand': 'verheiratet',
#   'Beruf': 'Drogist'},
#  {'PatientenID': 'ba2b1ae3-00c1-44ef-9426-ac7f30acd5b3',
#   'Versichertennummer': 'BU2036210',
#   'Vorname': 'Rita',
#   'Nachname': 'Scheel',
#   'Geburtsdatum': datetime.date(1994, 2, 20),
#   'Geschlecht': 'weiblich',
#   'Adresse': 'Alberto-Walter-Allee 4-4, 71848 Augsburg',
#   'Telefon': '07223 097605',
#   'Email': 'sinahethur@example.org',
#   'Blutgruppe': 'A-',
#   'Letzer_Besuch': datetime.date(2025, 5, 1),
#   'Hausarzt': 'Brunhilde Klapp',
#   'Größe_cm': 184,
#   'Gewicht_kg': 85,
#   'Raucher': True,
#   'Allergien': 'keine',
#   'Letzes_EKG': datetime.date(2025, 2, 15),
#   'BMI': 25.2,
#   'Familienstand': 'geschieden',
#   'Beruf': 'Pilot'},
#  {'PatientenID': '1722e91e-7930-4001-ba65-1fd70e0a7de7',
#   'Versichertennummer': 'WZ4217453',
#   'Vorname': 'Lea',
#   'Nachname': 'Renner',
#   'Geburtsdatum': datetime.date(1949, 7, 23),
#   'Geschlecht': 'divers',
#   'Adresse': 'Sorgatzgasse 4/3, 14099 Lichtenfels',
#   'Telefon': '+49(0)6521 98179',
#   'Email': 'schaafbogdan@example.net',
#   'Blutgruppe': 'AB+',
#   'Letzer_Besuch': datetime.date(2025, 4, 8),
#   'Hausarzt': 'Hans Jürgen Beer',
#   'Größe_cm': 176,
#   'Gewicht_kg': 121,
#   'Raucher': False,
#   'Allergien': 'Nüsse',
#   'Letzes_EKG': datetime.date(2025, 7, 7),
#   'BMI': 22.2,
#   'Familienstand': 'ledig',
#   'Beruf': 'Bäcker'},
#  {'PatientenID': 'f14f14ae-059e-4ca1-9952-48056ce3b7f6',
#   'Versichertennummer': 'CG7119305',
#   'Vorname': 'Jörg-Peter',
#   'Nachname': 'Schottin',
#   'Geburtsdatum': datetime.date(1987, 12, 15),
#   'Geschlecht': 'divers',
#   'Adresse': 'Walter-Adolph-Ring 8, 89546 Schwandorf',
#   'Telefon': '+49(0) 032965683',
#   'Email': 'erdoganharloff@example.org',
#   'Blutgruppe': 'O-',
#   'Letzer_Besuch': datetime.date(2025, 7, 18),
#   'Hausarzt': 'Jasmin Cichorius',
#   'Größe_cm': 218,
#   'Gewicht_kg': 121,
#   'Raucher': False,
#   'Allergien': 'Nüsse',
#   'Letzes_EKG': datetime.date(2025, 5, 20),
#   'BMI': 29.0,
#   'Familienstand': 'ledig',
#   'Beruf': 'Beamter'},
#  {'PatientenID': 'a80ac171-c83f-4909-9c02-56302fb47088',
#   'Versichertennummer': 'AC1798960',
#   'Vorname': 'Annemarie',
#   'Nachname': 'Staude',
#   'Geburtsdatum': datetime.date(1989, 4, 21),
#   'Geschlecht': 'männlich',
#   'Adresse': 'Karzgasse 269, 82594 Staßfurt',
#   'Telefon': '+49(0) 071040262',
#   'Email': 'renneryusuf@example.org',
#   'Blutgruppe': 'AB+',
#   'Letzer_Besuch': datetime.date(2025, 1, 31),
#   'Hausarzt': 'Hubertine Fritsch',
#   'Größe_cm': 217,
#   'Gewicht_kg': 114,
#   'Raucher': False,
#   'Allergien': 'Nüsse',
#   'Letzes_EKG': datetime.date(2025, 5, 30),
#   'BMI': 19.2,
#   'Familienstand': 'verwitwet',
#   'Beruf': 'Artist'},
#  {'PatientenID': '478d3150-21ce-4efa-b641-ccc8477b4b58',
#   'Versichertennummer': 'DX2820879',
#   'Vorname': 'Marijan',
#   'Nachname': 'Harloff',
#   'Geburtsdatum': datetime.date(2006, 8, 13),
#   'Geschlecht': 'weiblich',
#   'Adresse': 'Carmela-Säuberlich-Weg 2219, 08754 Nördlingen',
#   'Telefon': '0304650227',
#   'Email': 'doerschnerirmingard@example.org',
#   'Blutgruppe': 'O+',
#   'Letzer_Besuch': datetime.date(2025, 3, 19),
#   'Hausarzt': 'Marisa Rudolph',
#   'Größe_cm': 191,
#   'Gewicht_kg': 71,
#   'Raucher': True,
#   'Allergien': 'Nüsse',
#   'Letzes_EKG': datetime.date(2025, 4, 6),
#   'BMI': 30.5,
#   'Familienstand': 'geschieden',
#   'Beruf': 'Fachinformatiker'},
#  {'PatientenID': 'cdcc3848-2743-4ca0-a375-608207931a91',
#   'Versichertennummer': 'HD1214882',
#   'Vorname': 'Henny',
#   'Nachname': 'Mohaupt',
#   'Geburtsdatum': datetime.date(2022, 5, 4),
#   'Geschlecht': 'divers',
#   'Adresse': 'Annegret-Birnbaum-Gasse 425, 87700 Parchim',
#   'Telefon': '0362330974',
#   'Email': 'sueleymanhendriks@example.com',
#   'Blutgruppe': 'O+',
#   'Letzer_Besuch': datetime.date(2025, 2, 15),
#   'Hausarzt': 'Imelda Seifert',
#   'Größe_cm': 166,
#   'Gewicht_kg': 92,
#   'Raucher': True,
#   'Allergien': 'Gluten',
#   'Letzes_EKG': datetime.date(2025, 2, 27),
#   'BMI': 31.0,
#   'Familienstand': 'verwitwet',
#   'Beruf': 'Krankenschwester'},
#  {'PatientenID': '629b5cc8-2d52-4c81-b791-ecbcf7783b91',
#   'Versichertennummer': 'ZN9371298',
#   'Vorname': 'Willibert',
#   'Nachname': 'Kraus',
#   'Geburtsdatum': datetime.date(1951, 10, 23),
#   'Geschlecht': 'weiblich',
#   'Adresse': 'Hansgeorg-Börner-Straße 14, 09075 Freising',
#   'Telefon': '(02243) 866199',
#   'Email': 'eschmidtke@example.org',
#   'Blutgruppe': 'A+',
#   'Letzer_Besuch': datetime.date(2025, 2, 11),
#   'Hausarzt': 'Cemil Siering',
#   'Größe_cm': 209,
#   'Gewicht_kg': 41,
#   'Raucher': False,
#   'Allergien': 'Nüsse',
#   'Letzes_EKG': datetime.date(2025, 7, 9),
#   'BMI': 23.0,
#   'Familienstand': 'ledig',
#   'Beruf': 'Augenoptiker'},
#  {'PatientenID': '8e4deccb-fe7e-4b61-89f2-9bda4a4d5685',
#   'Versichertennummer': 'TL8727212',
#   'Vorname': 'Lioba',
#   'Nachname': 'Pruschke',
#   'Geburtsdatum': datetime.date(2000, 5, 20),
#   'Geschlecht': 'divers',
#   'Adresse': 'Etzlerweg 921, 68074 Rockenhausen',
#   'Telefon': '(00031) 29053',
#   'Email': 'bogdanstadelmann@example.com',
#   'Blutgruppe': 'A-',
#   'Letzer_Besuch': datetime.date(2025, 6, 26),
#   'Hausarzt': 'Michelle Trommler',
#   'Größe_cm': 149,
#   'Gewicht_kg': 70,
#   'Raucher': False,
#   'Allergien': 'Milch',
#   'Letzes_EKG': datetime.date(2025, 3, 29),
#   'BMI': 21.1,
#   'Familienstand': 'verheiratet',
#   'Beruf': 'Pfleger'},
#  {'PatientenID': 'c98ad803-3d1b-4afc-b30f-e95a8f18da13',
#   'Versichertennummer': 'OA2594297',
#   'Vorname': 'Alois',
#   'Nachname': 'Martin',
#   'Geburtsdatum': datetime.date(2022, 2, 27),
#   'Geschlecht': 'divers',
#   'Adresse': 'Sara-Patberg-Weg 2-4, 33971 Einbeck',
#   'Telefon': '+49(0)0070646660',
#   'Email': 'jeannettetintzmann@example.net',
#   'Blutgruppe': 'B+',
#   'Letzer_Besuch': datetime.date(2025, 7, 3),
#   'Hausarzt': 'Gerolf Jäkel',
#   'Größe_cm': 176,
#   'Gewicht_kg': 63,
#   'Raucher': False,
#   'Allergien': 'Pollen',
#   'Letzes_EKG': datetime.date(2025, 7, 13),
#   'BMI': 29.7,
#   'Familienstand': 'verheiratet',
#   'Beruf': 'Asphaltbauer'},
#  ...]

# %%
df = pd.DataFrame(patienten)
df
# Out:
#                                 PatientenID Versichertennummer    Vorname  \
# 0      b24ff43e-a903-4789-b2f6-4056773e3a06          AQ2755005   Svetlana
# 1      fbffa844-ec1d-4f20-9a0b-5474dfcaf702          XB8073653      Linda
# 2      65d26661-3f6a-4d52-847d-d722d7d0cc25          XC1598876   Karoline
# 3      def9fe72-2ba0-44d8-bbf5-fe9c8df803a1          HP3422006     Andrew
# 4      da1bc0e2-73bd-4ccb-abb5-0b6b180266a1          SP6375505      James
# ...                                     ...                ...        ...
# 49995  0a3b1093-4663-4120-8bc2-1197ce154368          GZ1982764      Ivana
# 49996  08fa3657-bdd6-43ba-b60b-d700f670d008          XI4160721       Anke
# 49997  2642b74a-a90e-4b84-8129-be66d9bcdc42          BL2954542     Moritz
# 49998  907cc2ce-8c66-4e7a-87c1-5149879b67ab          TX5400491  Stephanie
# 49999  662acc24-641b-4c63-91da-63613720c9fd          RX2993627       Hajo
#
#          Nachname Geburtsdatum Geschlecht  \
# 0          Scholz   1975-03-11   weiblich
# 1       Ackermann   1978-03-17     divers
# 2         Jüttner   1937-09-27   weiblich
# 3          Kobelt   1960-09-23   weiblich
# 4         Stiffel   1951-06-21     divers
# ...           ...          ...        ...
# 49995       Thies   2016-05-13     divers
# 49996       Budig   1935-12-27   männlich
# 49997       Rogge   1930-04-07   weiblich
# 49998      Müller   1974-09-23   weiblich
# 49999  Gierschner   2013-06-25   männlich
#
#                                                  Adresse           Telefon  \
# 0                          Fechnerring 6-5, 88532 Erding      07311 236676
# 1                        Wähnerweg 7/5, 57649 Euskirchen  +49(0)6282711059
# 2                   Frida-Höfig-Ring 41/17, 37134 Dachau  +49(0)7142 95095
# 3                Ole-Schmiedt-Straße 38, 42082 Hechingen      06705 142476
# 4               Wolfgang-Förster-Gasse 65/17, 16662 Roth  +49(0)1601 00257
# ...                                                  ...               ...
# 49995  Juliane-Drub-Weg 4552, 79928 Rothenburg ob der...       00210357569
# 49996                     Bolzmannallee 7-1, 50877 Borna       03151 77049
# 49997  Hans Josef-Kostolzin-Ring 98/78, 98384 Ludwigs...     (07597) 79576
# 49998                 Atzlerstraße 3-1, 23288 Regensburg      00078 011735
# 49999          Kristine-Pölitz-Weg 4-3, 89851 Wittenberg  +49(0)0636971893
#
#                                Email Blutgruppe Letzer_Besuch  \
# 0            heckertabea@example.net         A-    2025-03-01
# 1              kargerene@example.org        AB+    2025-04-28
# 2          joachimjunitz@example.net         A+    2025-03-11
# 3      wilhelminelehmann@example.com         B-    2025-03-24
# 4               ulrike39@example.org        AB-    2025-07-28
# ...                              ...        ...           ...
# 49995    weitzelreinhild@example.com        AB-    2025-03-04
# 49996     marie-louise75@example.org        AB-    2025-05-13
# 49997             theo39@example.org        AB+    2025-04-28
# 49998       erwinsoeding@example.com         B+    2025-01-07
# 49999       sinaweinhage@example.net         A-    2025-07-21
#
#                      Hausarzt  Größe_cm  Gewicht_kg  Raucher Allergien  \
# 0               Cäcilie Kabus       149          74     True     Nüsse
# 1            Konstanze Binner       190          63    False    Pollen
# 2      Constance Hermighausen       169          68     True    Pollen
# 3               Erdogan Sauer       145          87    False     Milch
# 4          Marie-Therese Wiek       175         123    False     Milch
# ...                       ...       ...         ...      ...       ...
# 49995            Selma Pieper       206         115     True     Nüsse
# 49996           Erdogan Lorch       184          77     True     Nüsse
# 49997          Nikolas Seidel       164         113     True    Gluten
# 49998          Mehdi Niemeier       146          91    False    Gluten
# 49999      Jens-Peter Koch II       185         124     True     Nüsse
#
#        Letzes_EKG   BMI Familienstand                Beruf
# 0      2025-05-29  28.4    geschieden            Techniker
# 1      2025-04-20  30.4         ledig              Friseur
# 2      2025-07-10  26.5    geschieden               Bäcker
# 3      2025-07-25  30.6     verwitwet              Beamter
# 4      2025-03-10  32.7         ledig  Chirurgiemechaniker
# ...           ...   ...           ...                  ...
# 49995  2025-04-15  21.9     verwitwet     Schornsteinfeger
# 49996  2025-02-24  28.8     verwitwet            Techniker
# 49997  2025-03-24  33.9    geschieden            Techniker
# 49998  2025-03-10  21.1    geschieden              Friseur
# 49999  2025-01-29  25.0     verwitwet               Artist
#
# [50000 rows x 20 columns]

# %%
df.head(10) # die ersten 10 Eintragungen
# Out:
#                             PatientenID Versichertennummer   Vorname  \
# 0  b24ff43e-a903-4789-b2f6-4056773e3a06          AQ2755005  Svetlana
# 1  fbffa844-ec1d-4f20-9a0b-5474dfcaf702          XB8073653     Linda
# 2  65d26661-3f6a-4d52-847d-d722d7d0cc25          XC1598876  Karoline
# 3  def9fe72-2ba0-44d8-bbf5-fe9c8df803a1          HP3422006    Andrew
# 4  da1bc0e2-73bd-4ccb-abb5-0b6b180266a1          SP6375505     James
# 5  3cacc5de-ec2a-44f2-a340-7d3eecd3352b          PG9563299   Folkert
# 6  b27d2dcc-8457-40fd-9581-7f4a8934ab3b          OS9331247      Amir
# 7  2a38c998-2412-4551-89bb-ea30fe16ea6f          QV1422301    Danilo
# 8  e07d4739-8d34-4b46-b638-d158361066c2          ZR6900724    Heiner
# 9  fefaa244-30bf-4d10-a889-289393781443          NU2272781    Galina
#
#     Nachname Geburtsdatum Geschlecht  \
# 0     Scholz   1975-03-11   weiblich
# 1  Ackermann   1978-03-17     divers
# 2    Jüttner   1937-09-27   weiblich
# 3     Kobelt   1960-09-23   weiblich
# 4    Stiffel   1951-06-21     divers
# 5      Mühle   2004-11-25     divers
# 6        Heß   1990-10-03     divers
# 7      Ernst   1994-07-05   weiblich
# 8      Trapp   1953-09-29     divers
# 9      Gnatz   2018-01-23     divers
#
#                                              Adresse              Telefon  \
# 0                      Fechnerring 6-5, 88532 Erding         07311 236676
# 1                    Wähnerweg 7/5, 57649 Euskirchen     +49(0)6282711059
# 2               Frida-Höfig-Ring 41/17, 37134 Dachau     +49(0)7142 95095
# 3            Ole-Schmiedt-Straße 38, 42082 Hechingen         06705 142476
# 4           Wolfgang-Förster-Gasse 65/17, 16662 Roth     +49(0)1601 00257
# 5            Florence-Karge-Weg 378, 32779 Forchheim       (05372) 589718
# 6  Margret-Säuberlich-Ring 4/5, 43157 Eisenhütten...  +49 (0) 7729 632372
# 7                  Trommlerplatz 27, 36800 Steinfurt     +49(0)8941 28175
# 8           André-Bärer-Allee 7/4, 87262 Eggenfelden           0018694646
# 9          Leila-Stroh-Ring 1-4, 49414 Bischofswerda           0765777254
#
#                            Email Blutgruppe Letzer_Besuch  \
# 0        heckertabea@example.net         A-    2025-03-01
# 1          kargerene@example.org        AB+    2025-04-28
# 2      joachimjunitz@example.net         A+    2025-03-11
# 3  wilhelminelehmann@example.com         B-    2025-03-24
# 4           ulrike39@example.org        AB-    2025-07-28
# 5         bennodietz@example.com         A+    2025-06-20
# 6             zwirth@example.com         B-    2025-04-15
# 7       gueltenlange@example.com         A+    2025-02-10
# 8       steckeldarko@example.org        AB-    2025-01-15
# 9          karztabea@example.net         O-    2025-01-17
#
#                  Hausarzt  Größe_cm  Gewicht_kg  Raucher Allergien  \
# 0           Cäcilie Kabus       149          74     True     Nüsse
# 1        Konstanze Binner       190          63    False    Pollen
# 2  Constance Hermighausen       169          68     True    Pollen
# 3           Erdogan Sauer       145          87    False     Milch
# 4      Marie-Therese Wiek       175         123    False     Milch
# 5    Ortwin Freudenberger       160          75    False     Nüsse
# 6             Ines Dowerg       210          82    False    Gluten
# 7               Pius Bähr       161          41    False    Pollen
# 8              Gaby Bloch       169          53     True    Gluten
# 9            Therese Bien       162         126     True    Pollen
#
#    Letzes_EKG   BMI Familienstand                Beruf
# 0  2025-05-29  28.4    geschieden            Techniker
# 1  2025-04-20  30.4         ledig              Friseur
# 2  2025-07-10  26.5    geschieden               Bäcker
# 3  2025-07-25  30.6     verwitwet              Beamter
# 4  2025-03-10  32.7         ledig  Chirurgiemechaniker
# 5  2025-01-14  29.3   verheiratet   Ausbaufacharbeiter
# 6  2025-02-20  25.2   verheiratet              Friseur
# 7  2025-02-17  31.6   verheiratet        Koreanistiker
# 8  2025-05-10  21.7         ledig             Designer
# 9  2025-06-06  27.9    geschieden              Pfleger

# %%
df.tail(10) # die letzten 10 Eintragungen
# Out:
#                                 PatientenID Versichertennummer      Vorname  \
# 49990  d76a4a2f-a5f4-44b7-8f4b-609c076658fc          FM1513899        Cemal
# 49991  861715d2-18ec-4b14-9827-9bae97be18e8          VN3072779  Hans-Werner
# 49992  8fdeb78b-fe41-4738-8878-ffb5a969b307          MS6815126     Marcella
# 49993  eacb19e2-3bff-4125-ba80-e1b32b55440e          RS9213272      Hans-J.
# 49994  ec73061e-d38d-4e34-8914-3e730c453a99          OO3005668        Jacob
# 49995  0a3b1093-4663-4120-8bc2-1197ce154368          GZ1982764        Ivana
# 49996  08fa3657-bdd6-43ba-b60b-d700f670d008          XI4160721         Anke
# 49997  2642b74a-a90e-4b84-8129-be66d9bcdc42          BL2954542       Moritz
# 49998  907cc2ce-8c66-4e7a-87c1-5149879b67ab          TX5400491    Stephanie
# 49999  662acc24-641b-4c63-91da-63613720c9fd          RX2993627         Hajo
#
#             Nachname Geburtsdatum Geschlecht  \
# 49990  Freudenberger   1926-03-25   weiblich
# 49991          Kraus   1934-01-13   weiblich
# 49992       Paffrath   1998-06-08     divers
# 49993         Adolph   1955-01-07     divers
# 49994        Ullmann   1988-07-22   weiblich
# 49995          Thies   2016-05-13     divers
# 49996          Budig   1935-12-27   männlich
# 49997          Rogge   1930-04-07   weiblich
# 49998         Müller   1974-09-23   weiblich
# 49999     Gierschner   2013-06-25   männlich
#
#                                                  Adresse            Telefon  \
# 49990         Tschentscherstraße 7069, 56040 Schweinfurt      (03601) 23997
# 49991             Otmar-Stiebitz-Ring 58/72, 26753 Moers   +49(0)4508 27715
# 49992              Amir-Beer-Allee 54-33, 58055 Herzberg     (02132) 254350
# 49993            Emma-Kramer-Platz 11/64, 13647 Miesbach        00579165394
# 49994                     Textorweg 6-9, 96490 Meiningen  +49(0)4737 309581
# 49995  Juliane-Drub-Weg 4552, 79928 Rothenburg ob der...        00210357569
# 49996                     Bolzmannallee 7-1, 50877 Borna        03151 77049
# 49997  Hans Josef-Kostolzin-Ring 98/78, 98384 Ludwigs...      (07597) 79576
# 49998                 Atzlerstraße 3-1, 23288 Regensburg       00078 011735
# 49999          Kristine-Pölitz-Weg 4-3, 89851 Wittenberg   +49(0)0636971893
#
#                              Email Blutgruppe Letzer_Besuch  \
# 49990  hesserose-marie@example.net         B-    2025-02-01
# 49991     tamararoemer@example.org         O+    2025-03-30
# 49992   gottfriedtrupp@example.com         B-    2025-02-15
# 49993        aloisia03@example.com        AB+    2025-05-22
# 49994         oliebelt@example.org         A+    2025-07-26
# 49995  weitzelreinhild@example.com        AB-    2025-03-04
# 49996   marie-louise75@example.org        AB-    2025-05-13
# 49997           theo39@example.org        AB+    2025-04-28
# 49998     erwinsoeding@example.com         B+    2025-01-07
# 49999     sinaweinhage@example.net         A-    2025-07-21
#
#                  Hausarzt  Größe_cm  Gewicht_kg  Raucher Allergien  \
# 49990          Alina Kade       169          63     True     Nüsse
# 49991      Andrea Benthin       140          66    False     Milch
# 49992    Rebekka Segebahn       152          56     True     keine
# 49993        Svea Bonbach       167          67     True     keine
# 49994     Andreas Lehmann       175         128     True     Milch
# 49995        Selma Pieper       206         115     True     Nüsse
# 49996       Erdogan Lorch       184          77     True     Nüsse
# 49997      Nikolas Seidel       164         113     True    Gluten
# 49998      Mehdi Niemeier       146          91    False    Gluten
# 49999  Jens-Peter Koch II       185         124     True     Nüsse
#
#        Letzes_EKG   BMI Familienstand             Beruf
# 49990  2025-05-01  29.4         ledig      Augenoptiker
# 49991  2025-02-01  21.4         ledig    Binnenschiffer
# 49992  2025-07-05  31.3     verwitwet  Fachinformatiker
# 49993  2025-03-18  25.0   verheiratet        Mechaniker
# 49994  2025-03-26  24.8   verheiratet     Programmierer
# 49995  2025-04-15  21.9     verwitwet  Schornsteinfeger
# 49996  2025-02-24  28.8     verwitwet         Techniker
# 49997  2025-03-24  33.9    geschieden         Techniker
# 49998  2025-03-10  21.1    geschieden           Friseur
# 49999  2025-01-29  25.0     verwitwet            Artist

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 20 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   PatientenID         50000 non-null  object
#  1   Versichertennummer  50000 non-null  object
#  2   Vorname             50000 non-null  object
#  3   Nachname            50000 non-null  object
#  4   Geburtsdatum        50000 non-null  object
#  5   Geschlecht          50000 non-null  object
#  6   Adresse             50000 non-null  object
#  7   Telefon             50000 non-null  object
#  8   Email               50000 non-null  object
#  9   Blutgruppe          50000 non-null  object
#  10  Letzer_Besuch       50000 non-null  object
#  11  Hausarzt            50000 non-null  object
#  12  Größe_cm            50000 non-null  int64
#  13  Gewicht_kg          50000 non-null  int64
#  14  Raucher             50000 non-null  bool
#  15  Allergien           50000 non-null  object
#  16  Letzes_EKG          50000 non-null  object
#  17  BMI                 50000 non-null  float64
#  18  Familienstand       50000 non-null  object
#  19  Beruf               50000 non-null  object
# dtypes: bool(1), float64(1), int64(2), object(16)
# memory usage: 7.3+ MB

# %%
df.BMI
# Out:
# 0        28.4
# 1        30.4
# 2        26.5
# 3        30.6
# 4        32.7
#          ...
# 49995    21.9
# 49996    28.8
# 49997    33.9
# 49998    21.1
# 49999    25.0
# Name: BMI, Length: 50000, dtype: float64

# %%
df[["Vorname","Nachname","Geburtsdatum"]] # Zugriff auf mehrere Spalten
# Out:
#          Vorname    Nachname Geburtsdatum
# 0       Svetlana      Scholz   1975-03-11
# 1          Linda   Ackermann   1978-03-17
# 2       Karoline     Jüttner   1937-09-27
# 3         Andrew      Kobelt   1960-09-23
# 4          James     Stiffel   1951-06-21
# ...          ...         ...          ...
# 49995      Ivana       Thies   2016-05-13
# 49996       Anke       Budig   1935-12-27
# 49997     Moritz       Rogge   1930-04-07
# 49998  Stephanie      Müller   1974-09-23
# 49999       Hajo  Gierschner   2013-06-25
#
# [50000 rows x 3 columns]

# %%
n_df = df[["Vorname","Nachname","Geburtsdatum"]].copy() # tiefe Kopie
n_df["Alter"] = pd.Timestamp("now").year - pd.to_datetime(n_df["Geburtsdatum"]).dt.year
n_df["Geschlecht"] = df["Geschlecht"]
n_df["Raucher"] = df["Raucher"]
# Frauen zwischen 18 und 30, Nichtraucherin
n_df[(n_df["Alter"] >= 18) & (n_df["Alter"] < 30) & (n_df["Geschlecht"] == "weiblich") & (~ n_df["Raucher"])].head()
# Out:
#          Vorname     Nachname Geburtsdatum  Alter Geschlecht  Raucher
# 113    Valentine       Zimmer   2002-11-30     23   weiblich    False
# 166     Hubertus     Buchholz   2003-09-29     22   weiblich    False
# 205      Tatiana       Hethur   2004-03-20     21   weiblich    False
# 216  Hans-Ludwig     Fröhlich   2006-07-27     19   weiblich    False
# 241     Hans-Uwe  Ditschlerin   2005-03-16     20   weiblich    False

# %%
n_df["BMI"] = df["BMI"]

def bmi_class(bmi):
    if bmi < 18.5:
        return "Untergewicht"
    elif bmi < 25:
        return "Normalgewicht"
    elif bmi < 30:
        return "Übergewicht"
    else:
        return "Adipositas"

n_df["BMI_Klasse"] = n_df["BMI"].apply(lambda bmi: bmi_class(bmi))

# Aufgabe: 
# Berechnen Sie die Altersgruppen als neue Spalte in n_df
# "Kind" (unter 18), "Erwachsen", "Senior" (ab 65)

def altersgruppe(alter):
    if alter<18:
        return "Kind"
    elif alter < 65:
        return "Erwachsen"
    else:
        return "Senior"

n_df["Altersgruppe"] = n_df["Alter"].apply(lambda alter: altersgruppe(alter))
n_df
# Out:
#          Vorname    Nachname Geburtsdatum  Alter Geschlecht  Raucher   BMI  \
# 0       Svetlana      Scholz   1975-03-11     50   weiblich     True  28.4
# 1          Linda   Ackermann   1978-03-17     47     divers    False  30.4
# 2       Karoline     Jüttner   1937-09-27     88   weiblich     True  26.5
# 3         Andrew      Kobelt   1960-09-23     65   weiblich    False  30.6
# 4          James     Stiffel   1951-06-21     74     divers    False  32.7
# ...          ...         ...          ...    ...        ...      ...   ...
# 49995      Ivana       Thies   2016-05-13      9     divers     True  21.9
# 49996       Anke       Budig   1935-12-27     90   männlich     True  28.8
# 49997     Moritz       Rogge   1930-04-07     95   weiblich     True  33.9
# 49998  Stephanie      Müller   1974-09-23     51   weiblich    False  21.1
# 49999       Hajo  Gierschner   2013-06-25     12   männlich     True  25.0
#
#           BMI_Klasse Altersgruppe
# 0        Übergewicht    Erwachsen
# 1         Adipositas    Erwachsen
# 2        Übergewicht       Senior
# 3         Adipositas       Senior
# 4         Adipositas       Senior
# ...              ...          ...
# 49995  Normalgewicht         Kind
# 49996    Übergewicht       Senior
# 49997     Adipositas       Senior
# 49998  Normalgewicht    Erwachsen
# 49999    Übergewicht         Kind
#
# [50000 rows x 9 columns]

# %%
def filter_normalgewicht(df):
    return df[df["BMI_Klasse"] == "Normalgewicht"]

def filter_altersgruppe(df,altersgruppe):
    return df[df["Altersgruppe"] == altersgruppe]



def blutgruppe_part(df,col):
    df["Blutgruppe"] = col
    return df[(df["Blutgruppe"]=="0+") | (df["Blutgruppe"] == "AB+")]



df_normalgewicht = (n_df
    .pipe(filter_normalgewicht)
    .sort_values("Alter", ascending =False)
)
# Data Transformation Pipeline
df_normerwachsen = (n_df
    .pipe(filter_normalgewicht)
    .pipe(filter_altersgruppe, "Erwachsen")
    .sort_values("Alter", ascending =False)
)
df_normerwachsen
# Out:
#          Vorname  Nachname Geburtsdatum  Alter Geschlecht  Raucher   BMI  \
# 14187  Wilfriede  Paffrath   1961-12-20     64   weiblich     True  20.3
# 49613     Regine    Köster   1961-12-20     64     divers     True  18.8
# 49597     Yvette  Hoffmann   1961-01-12     64   weiblich    False  18.8
# 10852      Jozef     Tröst   1961-11-30     64   weiblich     True  22.8
# 6149   Korbinian   Jungfer   1961-05-25     64   männlich    False  21.7
# ...          ...       ...          ...    ...        ...      ...   ...
# 20333      Micha     Naser   2007-02-12     18   weiblich     True  20.5
# 20285       Rudi     Gunpf   2007-03-02     18     divers    False  23.5
# 20237    Johanna    Zimmer   2007-04-07     18     divers     True  20.5
# 19880  Frederike    Bender   2007-09-30     18     divers     True  21.9
# 13         Kazim     Rogge   2007-11-21     18   männlich     True  23.9
#
#           BMI_Klasse Altersgruppe
# 14187  Normalgewicht    Erwachsen
# 49613  Normalgewicht    Erwachsen
# 49597  Normalgewicht    Erwachsen
# 10852  Normalgewicht    Erwachsen
# 6149   Normalgewicht    Erwachsen
# ...              ...          ...
# 20333  Normalgewicht    Erwachsen
# 20285  Normalgewicht    Erwachsen
# 20237  Normalgewicht    Erwachsen
# 19880  Normalgewicht    Erwachsen
# 13     Normalgewicht    Erwachsen
#
# [8472 rows x 9 columns]

# %%
# Aufgabe: 
# Schreiben Sie eine Pipeline, welche eine Spalte Blutgruppe zum df hinzufügt, nach Blutgruppe 0+ oder AB+ filtert und nur Kinder anzeigt.
# Wenden Sie die Pipeline auf n_df an.   

df_ = (n_df
    .pipe(blutgruppe_part,df["Blutgruppe"])
    .pipe(filter_altersgruppe, "Kind")
)

df_
# Out:
#          Vorname   Nachname Geburtsdatum  Alter Geschlecht  Raucher   BMI  \
# 12         Käthe      Dietz   2015-03-21     10   männlich     True  32.5
# 75          Axel      Linke   2010-11-03     15   weiblich    False  27.0
# 159    Silvester  Girschner   2011-04-07     14   weiblich     True  26.2
# 164        Ahmad      Klapp   2021-07-05      4     divers    False  35.7
# 209       Gülsen    Haering   2018-11-12      7   weiblich    False  34.3
# ...          ...        ...          ...    ...        ...      ...   ...
# 49785       Cora  Reinhardt   2024-04-30      1   weiblich     True  29.8
# 49796       Cord   Hoffmann   2014-10-15     11     divers     True  21.8
# 49832    Hendrik      Krein   2018-10-11      7   männlich    False  19.3
# 49852      Anett     Pechel   2015-11-29     10     divers    False  32.7
# 49877    Carmine    Kallert   2017-10-14      8   weiblich     True  20.8
#
#           BMI_Klasse Altersgruppe Blutgruppe
# 12        Adipositas         Kind        AB+
# 75       Übergewicht         Kind        AB+
# 159      Übergewicht         Kind        AB+
# 164       Adipositas         Kind        AB+
# 209       Adipositas         Kind        AB+
# ...              ...          ...        ...
# 49785    Übergewicht         Kind        AB+
# 49796  Normalgewicht         Kind        AB+
# 49832  Normalgewicht         Kind        AB+
# 49852     Adipositas         Kind        AB+
# 49877  Normalgewicht         Kind        AB+
#
# [1111 rows x 10 columns]

# %%
# Query - SQL-ähnliches Filtern
# Männer, BMI>30

n_df.query("Geschlecht == 'männlich' and BMI > 30")
# Out:
#             Vorname     Nachname Geburtsdatum  Alter Geschlecht  Raucher  \
# 12            Käthe        Dietz   2015-03-21     10   männlich     True
# 32       Karl-Josef        Bauer   1995-09-20     30   männlich     True
# 46           Ingrid         Beer   1953-07-08     72   männlich     True
# 54         Wojciech      Margraf   1934-09-02     91   männlich     True
# 65     Hans-Michael        Gnatz   1927-12-20     98   männlich    False
# ...             ...          ...          ...    ...        ...      ...
# 49945        Undine      Kallert   1984-12-21     41   männlich    False
# 49958      Nadeshda       Heuser   2007-05-20     18   männlich    False
# 49960      Marliese  Wagenknecht   1998-10-28     27   männlich    False
# 49969      Jaroslaw         Otto   1980-04-20     45   männlich    False
# 49975        Traute       Lindau   1987-04-01     38   männlich     True
#
#         BMI  BMI_Klasse Altersgruppe Blutgruppe
# 12     32.5  Adipositas         Kind        AB+
# 32     33.5  Adipositas    Erwachsen         A+
# 46     32.9  Adipositas       Senior         O+
# 54     34.3  Adipositas       Senior         A+
# 65     34.3  Adipositas       Senior         B-
# ...     ...         ...          ...        ...
# 49945  33.7  Adipositas    Erwachsen         B+
# 49958  30.5  Adipositas    Erwachsen         B+
# 49960  33.4  Adipositas    Erwachsen         O+
# 49969  33.3  Adipositas    Erwachsen         B-
# 49975  34.4  Adipositas    Erwachsen         A-
#
# [5512 rows x 10 columns]

# %%
df
# Out:
#                                 PatientenID Versichertennummer    Vorname  \
# 0      b24ff43e-a903-4789-b2f6-4056773e3a06          AQ2755005   Svetlana
# 1      fbffa844-ec1d-4f20-9a0b-5474dfcaf702          XB8073653      Linda
# 2      65d26661-3f6a-4d52-847d-d722d7d0cc25          XC1598876   Karoline
# 3      def9fe72-2ba0-44d8-bbf5-fe9c8df803a1          HP3422006     Andrew
# 4      da1bc0e2-73bd-4ccb-abb5-0b6b180266a1          SP6375505      James
# ...                                     ...                ...        ...
# 49995  0a3b1093-4663-4120-8bc2-1197ce154368          GZ1982764      Ivana
# 49996  08fa3657-bdd6-43ba-b60b-d700f670d008          XI4160721       Anke
# 49997  2642b74a-a90e-4b84-8129-be66d9bcdc42          BL2954542     Moritz
# 49998  907cc2ce-8c66-4e7a-87c1-5149879b67ab          TX5400491  Stephanie
# 49999  662acc24-641b-4c63-91da-63613720c9fd          RX2993627       Hajo
#
#          Nachname Geburtsdatum Geschlecht  \
# 0          Scholz   1975-03-11   weiblich
# 1       Ackermann   1978-03-17     divers
# 2         Jüttner   1937-09-27   weiblich
# 3          Kobelt   1960-09-23   weiblich
# 4         Stiffel   1951-06-21     divers
# ...           ...          ...        ...
# 49995       Thies   2016-05-13     divers
# 49996       Budig   1935-12-27   männlich
# 49997       Rogge   1930-04-07   weiblich
# 49998      Müller   1974-09-23   weiblich
# 49999  Gierschner   2013-06-25   männlich
#
#                                                  Adresse           Telefon  \
# 0                          Fechnerring 6-5, 88532 Erding      07311 236676
# 1                        Wähnerweg 7/5, 57649 Euskirchen  +49(0)6282711059
# 2                   Frida-Höfig-Ring 41/17, 37134 Dachau  +49(0)7142 95095
# 3                Ole-Schmiedt-Straße 38, 42082 Hechingen      06705 142476
# 4               Wolfgang-Förster-Gasse 65/17, 16662 Roth  +49(0)1601 00257
# ...                                                  ...               ...
# 49995  Juliane-Drub-Weg 4552, 79928 Rothenburg ob der...       00210357569
# 49996                     Bolzmannallee 7-1, 50877 Borna       03151 77049
# 49997  Hans Josef-Kostolzin-Ring 98/78, 98384 Ludwigs...     (07597) 79576
# 49998                 Atzlerstraße 3-1, 23288 Regensburg      00078 011735
# 49999          Kristine-Pölitz-Weg 4-3, 89851 Wittenberg  +49(0)0636971893
#
#                                Email Blutgruppe Letzer_Besuch  \
# 0            heckertabea@example.net         A-    2025-03-01
# 1              kargerene@example.org        AB+    2025-04-28
# 2          joachimjunitz@example.net         A+    2025-03-11
# 3      wilhelminelehmann@example.com         B-    2025-03-24
# 4               ulrike39@example.org        AB-    2025-07-28
# ...                              ...        ...           ...
# 49995    weitzelreinhild@example.com        AB-    2025-03-04
# 49996     marie-louise75@example.org        AB-    2025-05-13
# 49997             theo39@example.org        AB+    2025-04-28
# 49998       erwinsoeding@example.com         B+    2025-01-07
# 49999       sinaweinhage@example.net         A-    2025-07-21
#
#                      Hausarzt  Größe_cm  Gewicht_kg  Raucher Allergien  \
# 0               Cäcilie Kabus       149          74     True     Nüsse
# 1            Konstanze Binner       190          63    False    Pollen
# 2      Constance Hermighausen       169          68     True    Pollen
# 3               Erdogan Sauer       145          87    False     Milch
# 4          Marie-Therese Wiek       175         123    False     Milch
# ...                       ...       ...         ...      ...       ...
# 49995            Selma Pieper       206         115     True     Nüsse
# 49996           Erdogan Lorch       184          77     True     Nüsse
# 49997          Nikolas Seidel       164         113     True    Gluten
# 49998          Mehdi Niemeier       146          91    False    Gluten
# 49999      Jens-Peter Koch II       185         124     True     Nüsse
#
#        Letzes_EKG   BMI Familienstand                Beruf
# 0      2025-05-29  28.4    geschieden            Techniker
# 1      2025-04-20  30.4         ledig              Friseur
# 2      2025-07-10  26.5    geschieden               Bäcker
# 3      2025-07-25  30.6     verwitwet              Beamter
# 4      2025-03-10  32.7         ledig  Chirurgiemechaniker
# ...           ...   ...           ...                  ...
# 49995  2025-04-15  21.9     verwitwet     Schornsteinfeger
# 49996  2025-02-24  28.8     verwitwet            Techniker
# 49997  2025-03-24  33.9    geschieden            Techniker
# 49998  2025-03-10  21.1    geschieden              Friseur
# 49999  2025-01-29  25.0     verwitwet               Artist
#
# [50000 rows x 20 columns]

# %%
# Gruppenweise Mittelwerte

agg_df = df.groupby(["Geschlecht", "Raucher"])[["Größe_cm", "Gewicht_kg", "BMI" ]].agg(
    [
        'mean', 
        'std',  # Standartabweichung
        'min', 
        'max',
    ]
) 

agg_df["Gewicht_kg"]["std"]
# Out:
# Geschlecht  Raucher
# divers      False      26.326542
#             True       26.153594
# männlich    False      26.232996
#             True       26.329325
# weiblich    False      26.254280
#             True       26.271550
# Name: std, dtype: float64

# %%
df.groupby(["Geschlecht", "Raucher"])[["Größe_cm", "Gewicht_kg", "BMI" ]].agg(
    {
        "Größe_cm": "mean",
        "Gewicht_kg": "mean",
        "BMI": "max",
    }
)
# Out:
#                       Größe_cm  Gewicht_kg   BMI
# Geschlecht Raucher
# divers     False    179.357433   85.124044  36.0
#            True     180.352687   85.193618  36.0
# männlich   False    179.794984   85.073481  36.0
#            True     179.808477   85.357056  36.0
# weiblich   False    180.435711   85.554343  36.0
#            True     179.723637   84.833413  36.0

# %%
# Aufgabe: 
# 1. Erstellen Sie eine Statistik zur durchschnittlichen Größe und Gewicht 
# je nach Altersgruppe. 
# 2. Geben Sie Altersgruppen mit durchschnittlichen Gewicht >= 85.1 an
df["Alter"] = pd.Timestamp("now").year - pd.to_datetime(n_df["Geburtsdatum"]).dt.year
df["Altersgruppe"] = df["Alter"].apply(lambda alter: altersgruppe(alter))


agg_df = df.groupby(["Altersgruppe"])[["Größe_cm", "Gewicht_kg" ]].mean()
agg_df[agg_df["Gewicht_kg"]>85.1]
# Out:
#                 Größe_cm  Gewicht_kg
# Altersgruppe
# Erwachsen     179.994841   85.190088
# Senior        179.804691   85.226063

# %%
agg_df.loc["Kind"] # Zeile auswählen
agg_df.loc["Kind", "Größe_cm"] # Wert in der Zeile "Kind" und Spalte "Größe_cm"
agg_df.loc[:,"Gewicht_kg"] # Spaltenauswahl in der Matrixnotation
agg_df.loc["Erwachsen":"Kind",:] # Slicing
df.loc[:500,"Vorname":] # Alle Spalten von "Vornamen" bis Ende, die ersten 500 Zeilen
df.loc[:,:"Raucher"] # alle Spalten bis "Raucher"
df.loc[100:200,"Hausarzt":"Familienstand"] # Zeile 100 bis Zeile 200, Spalte "Hausarzt" bis Spalte "Familienstand"
# Out:
#                  Hausarzt  Größe_cm  Gewicht_kg  Raucher Allergien  \
# 100  Franz-Josef Trommler       168         114     True     Nüsse
# 101        Josip Schleich       205         125    False     keine
# 102            Jane Karge       156         122     True     keine
# 103         Sylwia Ritter       204         123    False     Nüsse
# 104            Kathi Jähn       144          76     True    Pollen
# ..                    ...       ...         ...      ...       ...
# 196   Anne-Katrin Gorlitz       175         122     True     Nüsse
# 197      Dietrich Siering       147          70     True     keine
# 198            Katy Dietz       142         107     True    Gluten
# 199            Vitus Kohl       148         114    False     Nüsse
# 200        Irmela Hellwig       141         122    False    Pollen
#
#      Letzes_EKG   BMI Familienstand
# 100  2025-05-08  20.4   verheiratet
# 101  2025-01-19  23.7   verheiratet
# 102  2025-02-28  25.6     verwitwet
# 103  2025-05-20  22.9   verheiratet
# 104  2025-03-11  33.5     verwitwet
# ..          ...   ...           ...
# 196  2025-05-14  29.1   verheiratet
# 197  2025-03-15  31.0         ledig
# 198  2025-03-17  32.2         ledig
# 199  2025-04-20  31.6     verwitwet
# 200  2025-07-29  21.0    geschieden
#
# [101 rows x 8 columns]

# %%
# komplexere Auswahl

df.loc[[5,10],["Allergien","Größe_cm"]].loc[df["Alter"]>25]
# Out:
#    Allergien  Größe_cm
# 10    Gluten       157

# %%
df.loc[5,"Größe_cm"]
df.at[5,"Größe_cm"] # empfohlen bei Zugriff auf Einzelwerte
df.loc[5,"Größe_cm"] = 166  # Zuweisung
df.at[5,"Größe_cm"]
# Out:
# np.int64(166)

# %%
agg_df
# Out:
#                 Größe_cm  Gewicht_kg
# Altersgruppe
# Erwachsen     179.994841   85.190088
# Kind          179.901982   85.098743
# Senior        179.804691   85.226063

# %%
agg_df.iloc[1] # Zeile auswählen
agg_df.iloc[1, 0] # Wert in der Zeile "Kind" und Spalte "Größe_cm"
agg_df.iloc[:,1] # Spaltenauswahl in der Matrixnotation
agg_df.iloc[0:2,:] # Slicing
df.iloc[:500,2:] # Alle Spalten von "Vornamen" bis Ende, die ersten 500 Zeilen
df.iloc[:,:15] # alle Spalten bis "Raucher"
df.iloc[100:200,11:19] # Zeile 100 bis Zeile 200, Spalte "Hausarzt" bis Spalte "Familienstand"
# Out:
#                  Hausarzt  Größe_cm  Gewicht_kg  Raucher Allergien  \
# 100  Franz-Josef Trommler       168         114     True     Nüsse
# 101        Josip Schleich       205         125    False     keine
# 102            Jane Karge       156         122     True     keine
# 103         Sylwia Ritter       204         123    False     Nüsse
# 104            Kathi Jähn       144          76     True    Pollen
# ..                    ...       ...         ...      ...       ...
# 195           Axel Werner       179         108     True     Milch
# 196   Anne-Katrin Gorlitz       175         122     True     Nüsse
# 197      Dietrich Siering       147          70     True     keine
# 198            Katy Dietz       142         107     True    Gluten
# 199            Vitus Kohl       148         114    False     Nüsse
#
#      Letzes_EKG   BMI Familienstand
# 100  2025-05-08  20.4   verheiratet
# 101  2025-01-19  23.7   verheiratet
# 102  2025-02-28  25.6     verwitwet
# 103  2025-05-20  22.9   verheiratet
# 104  2025-03-11  33.5     verwitwet
# ..          ...   ...           ...
# 195  2025-06-21  28.1   verheiratet
# 196  2025-05-14  29.1   verheiratet
# 197  2025-03-15  31.0         ledig
# 198  2025-03-17  32.2         ledig
# 199  2025-04-20  31.6     verwitwet
#
# [100 rows x 8 columns]

# %%
df.to_pickle("patient.pk") # Pickle = binäres Serialisierungsformat
# Verwenden Sie nicht, wenn Sie nicht wissen wer und wie die Pickle-Datei
# erstellt worden ist.
